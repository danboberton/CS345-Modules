# %% [markdown]
# # Neural Networs and Keras
#
# This notebook is part of  course materials for CS 345: Machine Learning Foundations and Practice at Colorado State University.
# Original versions were created by Ben Sattelberg and Asa Ben-Hur with updates by Ross Beveridge.
#
# Last Update 4/07/2022
#
#
# *The text is released under the [CC BY-SA license](https://creativecommons.org/licenses/by-sa/4.0/), and code is released under the [MIT license](https://opensource.org/licenses/MIT).*

# %% [markdown]
# # Neural Networks

# %%
# %matplotlib inline
import numpy as np
from numpy.random import default_rng

import matplotlib.pyplot as plt
import matplotlib

from IPython import display
from base64 import b64decode

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import keras

import tensorflow as tf
#tf.compat.v1.enable_eager_execution()
tf.executing_eagerly()
# Out:
# False

# %% [markdown]
# ### Plotting functionality for later

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_XOR_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')

    delta = 0.01
    xmin=-0.1;xmax=1.1;ymin=-0.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-1, vmax=1)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    X = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
    y = np.array([1, 0, 0, 1])

    plt.style.use('default')
    ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()

#     ax2.plot_wireframe(x_grid, y_grid, Z, alpha=0.5);
#     ax2.scatter(X[:,0], X[:,1], y, c=y, alpha=1, s=20, cmap='bwr')

#     ax2.set_xlabel('$x_1$')
#     ax2.set_ylabel('$x_2$')
#     ax2.set_zlabel('f($x_1$, $x_2$)');

# %%
def plot_circles_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')
    
    r1 = 0.5
    r2 = np.sqrt(2*r1**2)
    r3 = np.sqrt(r1**2 + r2**2)

    delta = 0.01
    xmin=-1.1;xmax=1.1;ymin=-1.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-0.001, vmax=0.001)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    plt.style.use('default')
    #ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()
    
    circle = plt.Circle((0, 0), r1, alpha=0.5, edgecolor='k')
    annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, facecolor='r', alpha=0.5, edgecolor='k')
    ax.add_artist(circle)
    ax.add_artist(annulus)

# %% [markdown]
# ## Introduction to Keras

# %% [markdown]
# Last time we introduced neural networks and built a simple architecture we could use to (sometimes) solve the XOR problem.  We saw the challenge of programming a network with increasing numbers of units and layers.
#
# Fortunately, there exist a number of packages designed for neural networks use that automatically determine the correct update rules with backpropagation.  A few of the packages that are used in CSU's CS department are [TensorFlow](https://www.tensorflow.org), [PyTorch](https://pytorch.org), and [Keras](https://keras.io).  These packages use Python despite the fact that Python may be relatively slow compared to compiled languages.  These deep learning packages often compile their code into those faster languages or are able to take advantage of optimizations that give competitive performance.
#
# We'll use Keras with a TensorFlow backend as it is simple to use and competitive with other options.

# %% [markdown]
# The [Keras website](https://keras.io/) has good tutorials and documentation.

# %% [markdown]
# First, we will create our dataset - the same XOR problem discussed in the previous notebook.  The only difference is that we convert the input values to be 32 bit floating point values, rather than 64 bit.  This isn't strictly necessary, but most neural network packages use 32 bit floats because the added precision is not worth the memory and computational cost.

# %%
X_xor = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
y_xor = np.array([1, 0, 0, 1])

X_xor = X_xor.astype('float32')

# %% [markdown]
# Now we can set up a network.  We will use a ```Sequential``` network, which is the container for a multilayer perceptron/feedforward neural network structure. Keep in mind this is exactly the general type of network introduced in the multi-layer perceptron buildt from scratch earlier.

# %%
network1 = keras.Sequential()

# %% [markdown]
# Now we can add layers to it.  The first layer we add is our hidden layer.  Having two nodes would give us a network which *can* work, but frequently doesn't, so let's create a much larger network with ten nodes in its hidden layer.  This is referred to as a ```Dense``` layer, as every input has a weight connecting it to every node in the previous layer.  We also tell Keras to use the ReLU activation function for it.
#
# Finally, we will add a layer that transforms the outputs of the hidden layer into the single output value.  By not passing an activation function in, this defaults to having no activation function.

# %%
network1.add(keras.layers.Dense(10, activation='relu'))
network1.add(keras.layers.Dense(1))

# %% [markdown]
# This sets up a network that looks like this:

# %%
# Code here just allows image to be contained within this file
bar = '...'
display.Image(b64decode(bar),width=800)

# %% [markdown]
# Given the network, we can now set up the training process.  We will use the mean squared error as the loss function and use stochastic gradient descent as the optimzer:

# %%
loss_fn = keras.losses.MeanSquaredError()
opt     = keras.optimizers.SGD(learning_rate=0.005)

# %% [markdown]
# The command ```network.compile(...)``` constructs the network as something that can be trained or evaluated.  The ```metrics``` parameter accepts a list of values that we want to keep track of during the training process.

# %%
network1.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %% [markdown]
# With all of the set up out of the way, we are ready to train the network.  The ```batch_size``` controls how many inputs to pass through the network at a time.   With traditional gradient descent it would be every input and with traditional stochastic gradient descent it would be a single input.  The ```verbose``` parameter controls to what extent the network prints output reflecting its progress.  Notice that it keeps track of the loss used for training, and the 'accuracy' and 'mse' values that we passed as metrics of interest.  In this case the loss is MSE, so the two values are the same.

# %%
n_epochs = 512
history1 = network1.fit(X_xor, y_xor, batch_size=2, epochs=n_epochs, verbose=1)
# Out:
# WARNING:tensorflow:From /Users/ross/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/512
# 4/4 [==============================] - 0s 16ms/step - loss: 2.0475 - accuracy: 0.0000e+00 - mse: 2.0475
# Epoch 2/512
# 4/4 [==============================] - 0s 580us/step - loss: 1.8010 - accuracy: 0.0000e+00 - mse: 1.8010
# Epoch 3/512
# 4/4 [==============================] - 0s 516us/step - loss: 1.6174 - accuracy: 0.0000e+00 - mse: 1.6174
# Epoch 4/512
# 4/4 [==============================] - 0s 527us/step - loss: 1.4560 - accuracy: 0.5000 - mse: 1.4560
# Epoch 5/512
# 4/4 [==============================] - 0s 707us/step - loss: 1.3141 - accuracy: 0.5000 - mse: 1.3141
# Epoch 6/512
# 4/4 [==============================] - 0s 539us/step - loss: 1.1973 - accuracy: 0.5000 - mse: 1.1973
# Epoch 7/512
# 4/4 [==============================] - 0s 475us/step - loss: 1.0969 - accuracy: 0.5000 - mse: 1.0969
# Epoch 8/512
# 4/4 [==============================] - 0s 505us/step - loss: 1.0109 - accuracy: 0.5000 - mse: 1.0109
# Epoch 9/512
# 4/4 [==============================] - 0s 525us/step - loss: 0.9335 - accuracy: 0.5000 - mse: 0.9335
# Epoch 10/512
# 4/4 [==============================] - 0s 526us/step - loss: 0.8646 - accuracy: 0.5000 - mse: 0.8646
# Epoch 11/512
# 4/4 [==============================] - 0s 511us/step - loss: 0.8048 - accuracy: 0.5000 - mse: 0.8048
# Epoch 12/512
# 4/4 [==============================] - 0s 561us/step - loss: 0.7500 - accuracy: 0.5000 - mse: 0.7500
# Epoch 13/512
# 4/4 [==============================] - 0s 516us/step - loss: 0.7029 - accuracy: 0.5000 - mse: 0.7029
# Epoch 14/512
# 4/4 [==============================] - 0s 477us/step - loss: 0.6599 - accuracy: 0.5000 - mse: 0.6599
# Epoch 15/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.6193 - accuracy: 0.5000 - mse: 0.6193
# Epoch 16/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.5830 - accuracy: 0.5000 - mse: 0.5830
# Epoch 17/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.5519 - accuracy: 0.5000 - mse: 0.5519
# Epoch 18/512
# 4/4 [==============================] - 0s 526us/step - loss: 0.5255 - accuracy: 0.5000 - mse: 0.5255
# Epoch 19/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.4992 - accuracy: 0.5000 - mse: 0.4992
# Epoch 20/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.4774 - accuracy: 0.5000 - mse: 0.4774
# Epoch 21/512
# 4/4 [==============================] - 0s 466us/step - loss: 0.4594 - accuracy: 0.5000 - mse: 0.4594
# Epoch 22/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.4395 - accuracy: 0.5000 - mse: 0.4395
# Epoch 23/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.4242 - accuracy: 0.5000 - mse: 0.4242
# Epoch 24/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.4101 - accuracy: 0.5000 - mse: 0.4101
# Epoch 25/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.3977 - accuracy: 0.5000 - mse: 0.3977
# Epoch 26/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.3852 - accuracy: 0.5000 - mse: 0.3852
# Epoch 27/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.3742 - accuracy: 0.5000 - mse: 0.3742
# Epoch 28/512
# 4/4 [==============================] - 0s 471us/step - loss: 0.3646 - accuracy: 0.5000 - mse: 0.3646
# Epoch 29/512
# 4/4 [==============================] - 0s 542us/step - loss: 0.3547 - accuracy: 0.5000 - mse: 0.3547
# Epoch 30/512
# 4/4 [==============================] - 0s 513us/step - loss: 0.3459 - accuracy: 0.5000 - mse: 0.3459
# Epoch 31/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.3414 - accuracy: 0.5000 - mse: 0.3414
# Epoch 32/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.3340 - accuracy: 0.5000 - mse: 0.3340
# Epoch 33/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.3240 - accuracy: 0.5000 - mse: 0.3240
# Epoch 34/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.3175 - accuracy: 0.5000 - mse: 0.3175
# Epoch 35/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.3111 - accuracy: 0.5000 - mse: 0.3111
# Epoch 36/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.3060 - accuracy: 0.5000 - mse: 0.3060
# Epoch 37/512
# 4/4 [==============================] - 0s 500us/step - loss: 0.3009 - accuracy: 0.5000 - mse: 0.3009
# Epoch 38/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.2961 - accuracy: 0.5000 - mse: 0.2961
# Epoch 39/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.2951 - accuracy: 0.5000 - mse: 0.2951
# Epoch 40/512
# 4/4 [==============================] - 0s 470us/step - loss: 0.2874 - accuracy: 0.5000 - mse: 0.2874
# Epoch 41/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.2835 - accuracy: 0.5000 - mse: 0.2835
# Epoch 42/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.2836 - accuracy: 0.5000 - mse: 0.2836
# Epoch 43/512
# 4/4 [==============================] - 0s 444us/step - loss: 0.2766 - accuracy: 0.5000 - mse: 0.2766
# Epoch 44/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.2734 - accuracy: 0.5000 - mse: 0.2734
# Epoch 45/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.2708 - accuracy: 0.5000 - mse: 0.2708
# Epoch 46/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.2677 - accuracy: 0.5000 - mse: 0.2677
# Epoch 47/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.2652 - accuracy: 0.5000 - mse: 0.2652
# Epoch 48/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.2665 - accuracy: 0.5000 - mse: 0.2665
# Epoch 49/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.2607 - accuracy: 0.5000 - mse: 0.2607
# Epoch 50/512
# 4/4 [==============================] - 0s 466us/step - loss: 0.2622 - accuracy: 0.5000 - mse: 0.2622
# Epoch 51/512
# 4/4 [==============================] - 0s 422us/step - loss: 0.2565 - accuracy: 0.5000 - mse: 0.2565
# Epoch 52/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.2583 - accuracy: 0.5000 - mse: 0.2583
# Epoch 53/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.2530 - accuracy: 0.5000 - mse: 0.2530
# Epoch 54/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.2512 - accuracy: 0.5000 - mse: 0.2512
# Epoch 55/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.2496 - accuracy: 0.5000 - mse: 0.2496
# Epoch 56/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.2481 - accuracy: 0.5000 - mse: 0.2481
# Epoch 57/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.2467 - accuracy: 0.5000 - mse: 0.2467
# Epoch 58/512
# 4/4 [==============================] - 0s 602us/step - loss: 0.2453 - accuracy: 0.5000 - mse: 0.2453
# Epoch 59/512
# 4/4 [==============================] - 0s 553us/step - loss: 0.2477 - accuracy: 0.5000 - mse: 0.2477
# Epoch 60/512
# 4/4 [==============================] - 0s 580us/step - loss: 0.2430 - accuracy: 0.5000 - mse: 0.2430
# Epoch 61/512
# 4/4 [==============================] - 0s 763us/step - loss: 0.2418 - accuracy: 0.5000 - mse: 0.2418
# Epoch 62/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2442 - accuracy: 0.5000 - mse: 0.2442
# Epoch 63/512
# 4/4 [==============================] - 0s 780us/step - loss: 0.2431 - accuracy: 0.5000 - mse: 0.2431
# Epoch 64/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.5000 - mse: 0.2421
# Epoch 65/512
# 4/4 [==============================] - 0s 977us/step - loss: 0.2376 - accuracy: 0.5000 - mse: 0.2376
# Epoch 66/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2366 - accuracy: 0.5000 - mse: 0.2366
# Epoch 67/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2358 - accuracy: 0.5000 - mse: 0.2358
# Epoch 68/512
# 4/4 [==============================] - 0s 525us/step - loss: 0.2348 - accuracy: 0.5000 - mse: 0.2348
# Epoch 69/512
# 4/4 [==============================] - 0s 529us/step - loss: 0.2376 - accuracy: 0.5000 - mse: 0.2376
# Epoch 70/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.2331 - accuracy: 0.7500 - mse: 0.2331
# Epoch 71/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.2324 - accuracy: 0.7500 - mse: 0.2324
# Epoch 72/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.2352 - accuracy: 0.5000 - mse: 0.2352
# Epoch 73/512
# 4/4 [==============================] - 0s 484us/step - loss: 0.2310 - accuracy: 0.7500 - mse: 0.2310
# Epoch 74/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.2304 - accuracy: 0.7500 - mse: 0.2304
# Epoch 75/512
# 4/4 [==============================] - 0s 421us/step - loss: 0.2297 - accuracy: 0.7500 - mse: 0.2297
# Epoch 76/512
# 4/4 [==============================] - 0s 466us/step - loss: 0.2291 - accuracy: 0.7500 - mse: 0.2291
# Epoch 77/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.2288 - accuracy: 0.7500 - mse: 0.2288
# Epoch 78/512
# 4/4 [==============================] - 0s 535us/step - loss: 0.2282 - accuracy: 0.7500 - mse: 0.2282
# Epoch 79/512
# 4/4 [==============================] - 0s 522us/step - loss: 0.2278 - accuracy: 0.7500 - mse: 0.2278
# Epoch 80/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.2307 - accuracy: 0.7500 - mse: 0.2307
# Epoch 81/512
# 4/4 [==============================] - 0s 471us/step - loss: 0.2300 - accuracy: 0.7500 - mse: 0.2300
# Epoch 82/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.2262 - accuracy: 0.7500 - mse: 0.2262
# Epoch 83/512
# 4/4 [==============================] - 0s 774us/step - loss: 0.2290 - accuracy: 0.7500 - mse: 0.2290
# Epoch 84/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.2252 - accuracy: 0.7500 - mse: 0.2252
# Epoch 85/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.2248 - accuracy: 0.7500 - mse: 0.2248
# Epoch 86/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.2275 - accuracy: 0.7500 - mse: 0.2275
# Epoch 87/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.2274 - accuracy: 0.7500 - mse: 0.2274
# Epoch 88/512
# 4/4 [==============================] - 0s 443us/step - loss: 0.2232 - accuracy: 0.7500 - mse: 0.2232
# Epoch 89/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.2230 - accuracy: 0.7500 - mse: 0.2230
# Epoch 90/512
# 4/4 [==============================] - 0s 477us/step - loss: 0.2221 - accuracy: 0.7500 - mse: 0.2221
# Epoch 91/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.2220 - accuracy: 0.7500 - mse: 0.2220
# Epoch 92/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.2249 - accuracy: 0.7500 - mse: 0.2249
# Epoch 93/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.2209 - accuracy: 0.7500 - mse: 0.2209
# Epoch 94/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.2206 - accuracy: 0.7500 - mse: 0.2206
# Epoch 95/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.2235 - accuracy: 0.7500 - mse: 0.2235
# Epoch 96/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.2232 - accuracy: 0.7500 - mse: 0.2232
# Epoch 97/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.2226 - accuracy: 0.7500 - mse: 0.2226
# Epoch 98/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.2223 - accuracy: 0.7500 - mse: 0.2223
# Epoch 99/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.2218 - accuracy: 0.7500 - mse: 0.2218
# Epoch 100/512
# 4/4 [==============================] - 0s 443us/step - loss: 0.2182 - accuracy: 0.7500 - mse: 0.2182
# Epoch 101/512
# 4/4 [==============================] - 0s 613us/step - loss: 0.2209 - accuracy: 0.7500 - mse: 0.2209
# Epoch 102/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.2171 - accuracy: 0.7500 - mse: 0.2171
# Epoch 103/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.2168 - accuracy: 0.7500 - mse: 0.2168
# Epoch 104/512
# 4/4 [==============================] - 0s 538us/step - loss: 0.2164 - accuracy: 0.7500 - mse: 0.2164
# Epoch 105/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.2160 - accuracy: 0.7500 - mse: 0.2160
# Epoch 106/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.2155 - accuracy: 0.7500 - mse: 0.2155
# Epoch 107/512
# 4/4 [==============================] - 0s 583us/step - loss: 0.2183 - accuracy: 1.0000 - mse: 0.2183
# Epoch 108/512
# 4/4 [==============================] - 0s 672us/step - loss: 0.2181 - accuracy: 1.0000 - mse: 0.2181
# Epoch 109/512
# 4/4 [==============================] - 0s 741us/step - loss: 0.2174 - accuracy: 1.0000 - mse: 0.2174
# Epoch 110/512
# 4/4 [==============================] - 0s 833us/step - loss: 0.2139 - accuracy: 1.0000 - mse: 0.2139
# Epoch 111/512
# 4/4 [==============================] - 0s 756us/step - loss: 0.2168 - accuracy: 0.7500 - mse: 0.2168
# Epoch 112/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.2163 - accuracy: 0.7500 - mse: 0.2163
# Epoch 113/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.2160 - accuracy: 1.0000 - mse: 0.2160
# Epoch 114/512
# 4/4 [==============================] - 0s 426us/step - loss: 0.2123 - accuracy: 1.0000 - mse: 0.2123
# Epoch 115/512
# 4/4 [==============================] - 0s 439us/step - loss: 0.2118 - accuracy: 1.0000 - mse: 0.2118
# Epoch 116/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.2146 - accuracy: 1.0000 - mse: 0.2146
# Epoch 117/512
# 4/4 [==============================] - 0s 561us/step - loss: 0.2110 - accuracy: 1.0000 - mse: 0.2110
# Epoch 118/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.2105 - accuracy: 1.0000 - mse: 0.2105
# Epoch 119/512
# 4/4 [==============================] - 0s 630us/step - loss: 0.2134 - accuracy: 1.0000 - mse: 0.2134
# Epoch 120/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.2096 - accuracy: 1.0000 - mse: 0.2096
# Epoch 121/512
# 4/4 [==============================] - 0s 654us/step - loss: 0.2095 - accuracy: 1.0000 - mse: 0.2095
# Epoch 122/512
# 4/4 [==============================] - 0s 530us/step - loss: 0.2090 - accuracy: 1.0000 - mse: 0.2090
# Epoch 123/512
# 4/4 [==============================] - 0s 419us/step - loss: 0.2085 - accuracy: 1.0000 - mse: 0.2085
# Epoch 124/512
# 4/4 [==============================] - 0s 589us/step - loss: 0.2082 - accuracy: 1.0000 - mse: 0.2082
# Epoch 125/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.2110 - accuracy: 1.0000 - mse: 0.2110
# Epoch 126/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.2073 - accuracy: 1.0000 - mse: 0.2073
# Epoch 127/512
# 4/4 [==============================] - 0s 723us/step - loss: 0.2101 - accuracy: 1.0000 - mse: 0.2101
# Epoch 128/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.2100 - accuracy: 1.0000 - mse: 0.2100
# Epoch 129/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.2095 - accuracy: 1.0000 - mse: 0.2095
# Epoch 130/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.2090 - accuracy: 1.0000 - mse: 0.2090
# Epoch 131/512
# 4/4 [==============================] - 0s 727us/step - loss: 0.2087 - accuracy: 1.0000 - mse: 0.2087
# Epoch 132/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.2051 - accuracy: 1.0000 - mse: 0.2051
# Epoch 133/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.2047 - accuracy: 1.0000 - mse: 0.2047
# Epoch 134/512
# 4/4 [==============================] - 0s 598us/step - loss: 0.2041 - accuracy: 1.0000 - mse: 0.2041
# Epoch 135/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.2039 - accuracy: 1.0000 - mse: 0.2039
# Epoch 136/512
# 4/4 [==============================] - 0s 459us/step - loss: 0.2032 - accuracy: 1.0000 - mse: 0.2032
# Epoch 137/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.2031 - accuracy: 1.0000 - mse: 0.2031
# Epoch 138/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.2059 - accuracy: 1.0000 - mse: 0.2059
# Epoch 139/512
# 4/4 [==============================] - 0s 516us/step - loss: 0.2023 - accuracy: 1.0000 - mse: 0.2023
# Epoch 140/512
# 4/4 [==============================] - 0s 587us/step - loss: 0.2019 - accuracy: 1.0000 - mse: 0.2019
# Epoch 141/512
# 4/4 [==============================] - 0s 511us/step - loss: 0.2013 - accuracy: 1.0000 - mse: 0.2013
# Epoch 142/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.2012 - accuracy: 1.0000 - mse: 0.2012
# Epoch 143/512
# 4/4 [==============================] - 0s 655us/step - loss: 0.2037 - accuracy: 1.0000 - mse: 0.2037
# Epoch 144/512
# 4/4 [==============================] - 0s 672us/step - loss: 0.2036 - accuracy: 1.0000 - mse: 0.2036
# Epoch 145/512
# 4/4 [==============================] - 0s 590us/step - loss: 0.2031 - accuracy: 1.0000 - mse: 0.2031
# Epoch 146/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.1996 - accuracy: 1.0000 - mse: 0.1996
# Epoch 147/512
# 4/4 [==============================] - 0s 421us/step - loss: 0.2024 - accuracy: 1.0000 - mse: 0.2024
# Epoch 148/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.1985 - accuracy: 1.0000 - mse: 0.1985
# Epoch 149/512
# 4/4 [==============================] - 0s 511us/step - loss: 0.2016 - accuracy: 1.0000 - mse: 0.2016
# Epoch 150/512
# 4/4 [==============================] - 0s 493us/step - loss: 0.2011 - accuracy: 1.0000 - mse: 0.2011
# Epoch 151/512
# 4/4 [==============================] - 0s 470us/step - loss: 0.2006 - accuracy: 1.0000 - mse: 0.2006
# Epoch 152/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.1973 - accuracy: 1.0000 - mse: 0.1973
# Epoch 153/512
# 4/4 [==============================] - 0s 553us/step - loss: 0.1966 - accuracy: 1.0000 - mse: 0.1966
# Epoch 154/512
# 4/4 [==============================] - 0s 761us/step - loss: 0.1996 - accuracy: 1.0000 - mse: 0.1996
# Epoch 155/512
# 4/4 [==============================] - 0s 686us/step - loss: 0.1960 - accuracy: 1.0000 - mse: 0.1960
# Epoch 156/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.1986 - accuracy: 1.0000 - mse: 0.1986
# Epoch 157/512
# 4/4 [==============================] - 0s 447us/step - loss: 0.1984 - accuracy: 1.0000 - mse: 0.1984
# Epoch 158/512
# 4/4 [==============================] - 0s 432us/step - loss: 0.1948 - accuracy: 1.0000 - mse: 0.1948
# Epoch 159/512
# 4/4 [==============================] - 0s 491us/step - loss: 0.1944 - accuracy: 1.0000 - mse: 0.1944
# Epoch 160/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.1939 - accuracy: 1.0000 - mse: 0.1939
# Epoch 161/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.1937 - accuracy: 1.0000 - mse: 0.1937
# Epoch 162/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.1933 - accuracy: 1.0000 - mse: 0.1933
# Epoch 163/512
# 4/4 [==============================] - 0s 571us/step - loss: 0.1959 - accuracy: 1.0000 - mse: 0.1959
# Epoch 164/512
# 4/4 [==============================] - 0s 477us/step - loss: 0.1926 - accuracy: 1.0000 - mse: 0.1926
# Epoch 165/512
# 4/4 [==============================] - 0s 740us/step - loss: 0.1921 - accuracy: 1.0000 - mse: 0.1921
# Epoch 166/512
# 4/4 [==============================] - 0s 513us/step - loss: 0.1948 - accuracy: 1.0000 - mse: 0.1948
# Epoch 167/512
# 4/4 [==============================] - 0s 565us/step - loss: 0.1913 - accuracy: 1.0000 - mse: 0.1913
# Epoch 168/512
# 4/4 [==============================] - 0s 608us/step - loss: 0.1910 - accuracy: 1.0000 - mse: 0.1910
# Epoch 169/512
# 4/4 [==============================] - 0s 814us/step - loss: 0.1936 - accuracy: 1.0000 - mse: 0.1936
# Epoch 170/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.1900 - accuracy: 1.0000 - mse: 0.1900
# Epoch 171/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.1898 - accuracy: 1.0000 - mse: 0.1898
# Epoch 172/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.1894 - accuracy: 1.0000 - mse: 0.1894
# Epoch 173/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.1921 - accuracy: 1.0000 - mse: 0.1921
# Epoch 174/512
# 4/4 [==============================] - 0s 558us/step - loss: 0.1916 - accuracy: 1.0000 - mse: 0.1916
# Epoch 175/512
# 4/4 [==============================] - 0s 638us/step - loss: 0.1912 - accuracy: 1.0000 - mse: 0.1912
# Epoch 176/512
# 4/4 [==============================] - 0s 699us/step - loss: 0.1878 - accuracy: 1.0000 - mse: 0.1878
# Epoch 177/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.1873 - accuracy: 1.0000 - mse: 0.1873
# Epoch 178/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.1871 - accuracy: 1.0000 - mse: 0.1871
# Epoch 179/512
# 4/4 [==============================] - 0s 868us/step - loss: 0.1867 - accuracy: 1.0000 - mse: 0.1867
# Epoch 180/512
# 4/4 [==============================] - 0s 426us/step - loss: 0.1862 - accuracy: 1.0000 - mse: 0.1862
# Epoch 181/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.1859 - accuracy: 1.0000 - mse: 0.1859
# Epoch 182/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.1853 - accuracy: 1.0000 - mse: 0.1853
# Epoch 183/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.1882 - accuracy: 1.0000 - mse: 0.1882
# Epoch 184/512
# 4/4 [==============================] - 0s 533us/step - loss: 0.1877 - accuracy: 1.0000 - mse: 0.1877
# Epoch 185/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.1844 - accuracy: 1.0000 - mse: 0.1844
# Epoch 186/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.1869 - accuracy: 1.0000 - mse: 0.1869
# Epoch 187/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.1865 - accuracy: 1.0000 - mse: 0.1865
# Epoch 188/512
# 4/4 [==============================] - 0s 703us/step - loss: 0.1833 - accuracy: 1.0000 - mse: 0.1833
# Epoch 189/512
# 4/4 [==============================] - 0s 835us/step - loss: 0.1857 - accuracy: 1.0000 - mse: 0.1857
# Epoch 190/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.1824 - accuracy: 1.0000 - mse: 0.1824
# Epoch 191/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.1820 - accuracy: 1.0000 - mse: 0.1820
# Epoch 192/512
# 4/4 [==============================] - 0s 433us/step - loss: 0.1815 - accuracy: 1.0000 - mse: 0.1815
# Epoch 193/512
# 4/4 [==============================] - 0s 674us/step - loss: 0.1812 - accuracy: 1.0000 - mse: 0.1812
# Epoch 194/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.1837 - accuracy: 1.0000 - mse: 0.1837
# Epoch 195/512
# 4/4 [==============================] - 0s 557us/step - loss: 0.1804 - accuracy: 1.0000 - mse: 0.1804
# Epoch 196/512
# 4/4 [==============================] - 0s 433us/step - loss: 0.1829 - accuracy: 1.0000 - mse: 0.1829
# Epoch 197/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.1797 - accuracy: 1.0000 - mse: 0.1797
# Epoch 198/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.1793 - accuracy: 1.0000 - mse: 0.1793
# Epoch 199/512
# 4/4 [==============================] - 0s 582us/step - loss: 0.1789 - accuracy: 1.0000 - mse: 0.1789
# Epoch 200/512
# 4/4 [==============================] - 0s 729us/step - loss: 0.1785 - accuracy: 1.0000 - mse: 0.1785
# Epoch 201/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.1782 - accuracy: 1.0000 - mse: 0.1782
# Epoch 202/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.1806 - accuracy: 1.0000 - mse: 0.1806
# Epoch 203/512
# 4/4 [==============================] - 0s 557us/step - loss: 0.1773 - accuracy: 1.0000 - mse: 0.1773
# Epoch 204/512
# 4/4 [==============================] - 0s 577us/step - loss: 0.1769 - accuracy: 1.0000 - mse: 0.1769
# Epoch 205/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.1766 - accuracy: 1.0000 - mse: 0.1766
# Epoch 206/512
# 4/4 [==============================] - 0s 511us/step - loss: 0.1763 - accuracy: 1.0000 - mse: 0.1763
# Epoch 207/512
# 4/4 [==============================] - 0s 614us/step - loss: 0.1758 - accuracy: 1.0000 - mse: 0.1758
# Epoch 208/512
# 4/4 [==============================] - 0s 879us/step - loss: 0.1783 - accuracy: 1.0000 - mse: 0.1783
# Epoch 209/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.1779 - accuracy: 1.0000 - mse: 0.1779
# Epoch 210/512
# 4/4 [==============================] - 0s 409us/step - loss: 0.1773 - accuracy: 1.0000 - mse: 0.1773
# Epoch 211/512
# 4/4 [==============================] - 0s 447us/step - loss: 0.1743 - accuracy: 1.0000 - mse: 0.1743
# Epoch 212/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.1738 - accuracy: 1.0000 - mse: 0.1738
# Epoch 213/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.1736 - accuracy: 1.0000 - mse: 0.1736
# Epoch 214/512
# 4/4 [==============================] - 0s 522us/step - loss: 0.1759 - accuracy: 1.0000 - mse: 0.1759
# Epoch 215/512
# 4/4 [==============================] - 0s 681us/step - loss: 0.1727 - accuracy: 1.0000 - mse: 0.1727
# Epoch 216/512
# 4/4 [==============================] - 0s 721us/step - loss: 0.1750 - accuracy: 1.0000 - mse: 0.1750
# Epoch 217/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.1745 - accuracy: 1.0000 - mse: 0.1745
# Epoch 218/512
# 4/4 [==============================] - 0s 594us/step - loss: 0.1715 - accuracy: 1.0000 - mse: 0.1715
# Epoch 219/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.1712 - accuracy: 1.0000 - mse: 0.1712
# Epoch 220/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.1733 - accuracy: 1.0000 - mse: 0.1733
# Epoch 221/512
# 4/4 [==============================] - 0s 638us/step - loss: 0.1704 - accuracy: 1.0000 - mse: 0.1704
# Epoch 222/512
# 4/4 [==============================] - 0s 602us/step - loss: 0.1699 - accuracy: 1.0000 - mse: 0.1699
# Epoch 223/512
# 4/4 [==============================] - 0s 688us/step - loss: 0.1695 - accuracy: 1.0000 - mse: 0.1695
# Epoch 224/512
# 4/4 [==============================] - 0s 538us/step - loss: 0.1692 - accuracy: 1.0000 - mse: 0.1692
# Epoch 225/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.1688 - accuracy: 1.0000 - mse: 0.1688
# Epoch 226/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.1684 - accuracy: 1.0000 - mse: 0.1684
# Epoch 227/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.1681 - accuracy: 1.0000 - mse: 0.1681
# Epoch 228/512
# 4/4 [==============================] - 0s 657us/step - loss: 0.1703 - accuracy: 1.0000 - mse: 0.1703
# Epoch 229/512
# 4/4 [==============================] - 0s 459us/step - loss: 0.1672 - accuracy: 1.0000 - mse: 0.1672
# Epoch 230/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.1696 - accuracy: 1.0000 - mse: 0.1696
# Epoch 231/512
# 4/4 [==============================] - 0s 529us/step - loss: 0.1664 - accuracy: 1.0000 - mse: 0.1664
# Epoch 232/512
# 4/4 [==============================] - 0s 504us/step - loss: 0.1661 - accuracy: 1.0000 - mse: 0.1661
# Epoch 233/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.1655 - accuracy: 1.0000 - mse: 0.1655
# Epoch 234/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.1654 - accuracy: 1.0000 - mse: 0.1654
# Epoch 235/512
# 4/4 [==============================] - 0s 616us/step - loss: 0.1649 - accuracy: 1.0000 - mse: 0.1649
# Epoch 236/512
# 4/4 [==============================] - 0s 715us/step - loss: 0.1644 - accuracy: 1.0000 - mse: 0.1644
# Epoch 237/512
# 4/4 [==============================] - 0s 436us/step - loss: 0.1668 - accuracy: 1.0000 - mse: 0.1668
# Epoch 238/512
# 4/4 [==============================] - 0s 585us/step - loss: 0.1637 - accuracy: 1.0000 - mse: 0.1637
# Epoch 239/512
# 4/4 [==============================] - 0s 553us/step - loss: 0.1634 - accuracy: 1.0000 - mse: 0.1634
# Epoch 240/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.1629 - accuracy: 1.0000 - mse: 0.1629
# Epoch 241/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.1652 - accuracy: 1.0000 - mse: 0.1652
# Epoch 242/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.1622 - accuracy: 1.0000 - mse: 0.1622
# Epoch 243/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.1618 - accuracy: 1.0000 - mse: 0.1618
# Epoch 244/512
# 4/4 [==============================] - 0s 448us/step - loss: 0.1613 - accuracy: 1.0000 - mse: 0.1613
# Epoch 245/512
# 4/4 [==============================] - 0s 564us/step - loss: 0.1611 - accuracy: 1.0000 - mse: 0.1611
# Epoch 246/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.1606 - accuracy: 1.0000 - mse: 0.1606
# Epoch 247/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.1604 - accuracy: 1.0000 - mse: 0.1604
# Epoch 248/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.1598 - accuracy: 1.0000 - mse: 0.1598
# Epoch 249/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.1595 - accuracy: 1.0000 - mse: 0.1595
# Epoch 250/512
# 4/4 [==============================] - 0s 533us/step - loss: 0.1616 - accuracy: 1.0000 - mse: 0.1616
# Epoch 251/512
# 4/4 [==============================] - 0s 580us/step - loss: 0.1587 - accuracy: 1.0000 - mse: 0.1587
# Epoch 252/512
# 4/4 [==============================] - 0s 541us/step - loss: 0.1582 - accuracy: 1.0000 - mse: 0.1582
# Epoch 253/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.1580 - accuracy: 1.0000 - mse: 0.1580
# Epoch 254/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.1601 - accuracy: 1.0000 - mse: 0.1601
# Epoch 255/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.1596 - accuracy: 1.0000 - mse: 0.1596
# Epoch 256/512
# 4/4 [==============================] - 0s 589us/step - loss: 0.1593 - accuracy: 1.0000 - mse: 0.1593
# Epoch 257/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.1564 - accuracy: 1.0000 - mse: 0.1564
# Epoch 258/512
# 4/4 [==============================] - 0s 609us/step - loss: 0.1560 - accuracy: 1.0000 - mse: 0.1560
# Epoch 259/512
# 4/4 [==============================] - 0s 477us/step - loss: 0.1582 - accuracy: 1.0000 - mse: 0.1582
# Epoch 260/512
# 4/4 [==============================] - 0s 491us/step - loss: 0.1551 - accuracy: 1.0000 - mse: 0.1551
# Epoch 261/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.1548 - accuracy: 1.0000 - mse: 0.1548
# Epoch 262/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.1545 - accuracy: 1.0000 - mse: 0.1545
# Epoch 263/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.1565 - accuracy: 1.0000 - mse: 0.1565
# Epoch 264/512
# 4/4 [==============================] - 0s 570us/step - loss: 0.1537 - accuracy: 1.0000 - mse: 0.1537
# Epoch 265/512
# 4/4 [==============================] - 0s 663us/step - loss: 0.1556 - accuracy: 1.0000 - mse: 0.1556
# Epoch 266/512
# 4/4 [==============================] - 0s 470us/step - loss: 0.1531 - accuracy: 1.0000 - mse: 0.1531
# Epoch 267/512
# 4/4 [==============================] - 0s 488us/step - loss: 0.1525 - accuracy: 1.0000 - mse: 0.1525
# Epoch 268/512
# 4/4 [==============================] - 0s 538us/step - loss: 0.1522 - accuracy: 1.0000 - mse: 0.1522
# Epoch 269/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.1518 - accuracy: 1.0000 - mse: 0.1518
# Epoch 270/512
# 4/4 [==============================] - 0s 567us/step - loss: 0.1514 - accuracy: 1.0000 - mse: 0.1514
# Epoch 271/512
# 4/4 [==============================] - 0s 430us/step - loss: 0.1537 - accuracy: 1.0000 - mse: 0.1537
# Epoch 272/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.1508 - accuracy: 1.0000 - mse: 0.1508
# Epoch 273/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.1502 - accuracy: 1.0000 - mse: 0.1502
# Epoch 274/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.1500 - accuracy: 1.0000 - mse: 0.1500
# Epoch 275/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.1496 - accuracy: 1.0000 - mse: 0.1496
# Epoch 276/512
# 4/4 [==============================] - 0s 488us/step - loss: 0.1516 - accuracy: 1.0000 - mse: 0.1516
# Epoch 277/512
# 4/4 [==============================] - 0s 582us/step - loss: 0.1491 - accuracy: 1.0000 - mse: 0.1491
# Epoch 278/512
# 4/4 [==============================] - 0s 687us/step - loss: 0.1485 - accuracy: 1.0000 - mse: 0.1485
# Epoch 279/512
# 4/4 [==============================] - 0s 727us/step - loss: 0.1483 - accuracy: 1.0000 - mse: 0.1483
# Epoch 280/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.1480 - accuracy: 1.0000 - mse: 0.1480
# Epoch 281/512
# 4/4 [==============================] - 0s 436us/step - loss: 0.1475 - accuracy: 1.0000 - mse: 0.1475
# Epoch 282/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.1498 - accuracy: 1.0000 - mse: 0.1498
# Epoch 283/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.1494 - accuracy: 1.0000 - mse: 0.1494
# Epoch 284/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.1465 - accuracy: 1.0000 - mse: 0.1465
# Epoch 285/512
# 4/4 [==============================] - 0s 537us/step - loss: 0.1463 - accuracy: 1.0000 - mse: 0.1463
# Epoch 286/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.1483 - accuracy: 1.0000 - mse: 0.1483
# Epoch 287/512
# 4/4 [==============================] - 0s 539us/step - loss: 0.1454 - accuracy: 1.0000 - mse: 0.1454
# Epoch 288/512
# 4/4 [==============================] - 0s 719us/step - loss: 0.1451 - accuracy: 1.0000 - mse: 0.1451
# Epoch 289/512
# 4/4 [==============================] - 0s 429us/step - loss: 0.1448 - accuracy: 1.0000 - mse: 0.1448
# Epoch 290/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.1468 - accuracy: 1.0000 - mse: 0.1468
# Epoch 291/512
# 4/4 [==============================] - 0s 538us/step - loss: 0.1442 - accuracy: 1.0000 - mse: 0.1442
# Epoch 292/512
# 4/4 [==============================] - 0s 561us/step - loss: 0.1437 - accuracy: 1.0000 - mse: 0.1437
# Epoch 293/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.1459 - accuracy: 1.0000 - mse: 0.1459
# Epoch 294/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.1430 - accuracy: 1.0000 - mse: 0.1430
# Epoch 295/512
# 4/4 [==============================] - 0s 505us/step - loss: 0.1426 - accuracy: 1.0000 - mse: 0.1426
# Epoch 296/512
# 4/4 [==============================] - 0s 627us/step - loss: 0.1448 - accuracy: 1.0000 - mse: 0.1448
# Epoch 297/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.1444 - accuracy: 1.0000 - mse: 0.1444
# Epoch 298/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.1440 - accuracy: 1.0000 - mse: 0.1440
# Epoch 299/512
# 4/4 [==============================] - 0s 567us/step - loss: 0.1437 - accuracy: 1.0000 - mse: 0.1437
# Epoch 300/512
# 4/4 [==============================] - 0s 544us/step - loss: 0.1410 - accuracy: 1.0000 - mse: 0.1410
# Epoch 301/512
# 4/4 [==============================] - 0s 550us/step - loss: 0.1408 - accuracy: 1.0000 - mse: 0.1408
# Epoch 302/512
# 4/4 [==============================] - 0s 567us/step - loss: 0.1427 - accuracy: 1.0000 - mse: 0.1427
# Epoch 303/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.1423 - accuracy: 1.0000 - mse: 0.1423
# Epoch 304/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.1397 - accuracy: 1.0000 - mse: 0.1397
# Epoch 305/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.1416 - accuracy: 1.0000 - mse: 0.1416
# Epoch 306/512
# 4/4 [==============================] - 0s 749us/step - loss: 0.1412 - accuracy: 1.0000 - mse: 0.1412
# Epoch 307/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.1408 - accuracy: 1.0000 - mse: 0.1408
# Epoch 308/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.1382 - accuracy: 1.0000 - mse: 0.1382
# Epoch 309/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.1403 - accuracy: 1.0000 - mse: 0.1403
# Epoch 310/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.1398 - accuracy: 1.0000 - mse: 0.1398
# Epoch 311/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.1372 - accuracy: 1.0000 - mse: 0.1372
# Epoch 312/512
# 4/4 [==============================] - 0s 513us/step - loss: 0.1369 - accuracy: 1.0000 - mse: 0.1369
# Epoch 313/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.1366 - accuracy: 1.0000 - mse: 0.1366
# Epoch 314/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.1360 - accuracy: 1.0000 - mse: 0.1360
# Epoch 315/512
# 4/4 [==============================] - 0s 672us/step - loss: 0.1360 - accuracy: 1.0000 - mse: 0.1360
# Epoch 316/512
# 4/4 [==============================] - 0s 753us/step - loss: 0.1355 - accuracy: 1.0000 - mse: 0.1355
# Epoch 317/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.1352 - accuracy: 1.0000 - mse: 0.1352
# Epoch 318/512
# 4/4 [==============================] - 0s 592us/step - loss: 0.1348 - accuracy: 1.0000 - mse: 0.1348
# Epoch 319/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.1346 - accuracy: 1.0000 - mse: 0.1346
# Epoch 320/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.1341 - accuracy: 1.0000 - mse: 0.1341
# Epoch 321/512
# 4/4 [==============================] - 0s 597us/step - loss: 0.1360 - accuracy: 1.0000 - mse: 0.1360
# Epoch 322/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.1335 - accuracy: 1.0000 - mse: 0.1335
# Epoch 323/512
# 4/4 [==============================] - 0s 631us/step - loss: 0.1352 - accuracy: 1.0000 - mse: 0.1352
# Epoch 324/512
# 4/4 [==============================] - 0s 608us/step - loss: 0.1327 - accuracy: 1.0000 - mse: 0.1327
# Epoch 325/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.1344 - accuracy: 1.0000 - mse: 0.1344
# Epoch 326/512
# 4/4 [==============================] - 0s 566us/step - loss: 0.1344 - accuracy: 1.0000 - mse: 0.1344
# Epoch 327/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.1317 - accuracy: 1.0000 - mse: 0.1317
# Epoch 328/512
# 4/4 [==============================] - 0s 608us/step - loss: 0.1313 - accuracy: 1.0000 - mse: 0.1313
# Epoch 329/512
# 4/4 [==============================] - 0s 526us/step - loss: 0.1312 - accuracy: 1.0000 - mse: 0.1312
# Epoch 330/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.1308 - accuracy: 1.0000 - mse: 0.1308
# Epoch 331/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.1303 - accuracy: 1.0000 - mse: 0.1303
# Epoch 332/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.1300 - accuracy: 1.0000 - mse: 0.1300
# Epoch 333/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.1298 - accuracy: 1.0000 - mse: 0.1298
# Epoch 334/512
# 4/4 [==============================] - 0s 449us/step - loss: 0.1293 - accuracy: 1.0000 - mse: 0.1293
# Epoch 335/512
# 4/4 [==============================] - 0s 613us/step - loss: 0.1312 - accuracy: 1.0000 - mse: 0.1312
# Epoch 336/512
# 4/4 [==============================] - 0s 537us/step - loss: 0.1286 - accuracy: 1.0000 - mse: 0.1286
# Epoch 337/512
# 4/4 [==============================] - 0s 557us/step - loss: 0.1283 - accuracy: 1.0000 - mse: 0.1283
# Epoch 338/512
# 4/4 [==============================] - 0s 695us/step - loss: 0.1281 - accuracy: 1.0000 - mse: 0.1281
# Epoch 339/512
# 4/4 [==============================] - 0s 574us/step - loss: 0.1276 - accuracy: 1.0000 - mse: 0.1276
# Epoch 340/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.1273 - accuracy: 1.0000 - mse: 0.1273
# Epoch 341/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.1269 - accuracy: 1.0000 - mse: 0.1269
# Epoch 342/512
# 4/4 [==============================] - 0s 624us/step - loss: 0.1287 - accuracy: 1.0000 - mse: 0.1287
# Epoch 343/512
# 4/4 [==============================] - 0s 516us/step - loss: 0.1263 - accuracy: 1.0000 - mse: 0.1263
# Epoch 344/512
# 4/4 [==============================] - 0s 653us/step - loss: 0.1279 - accuracy: 1.0000 - mse: 0.1279
# Epoch 345/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.1277 - accuracy: 1.0000 - mse: 0.1277
# Epoch 346/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.1251 - accuracy: 1.0000 - mse: 0.1251
# Epoch 347/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.1248 - accuracy: 1.0000 - mse: 0.1248
# Epoch 348/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.1243 - accuracy: 1.0000 - mse: 0.1243
# Epoch 349/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.1264 - accuracy: 1.0000 - mse: 0.1264
# Epoch 350/512
# 4/4 [==============================] - 0s 463us/step - loss: 0.1238 - accuracy: 1.0000 - mse: 0.1238
# Epoch 351/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.1234 - accuracy: 1.0000 - mse: 0.1234
# Epoch 352/512
# 4/4 [==============================] - 0s 561us/step - loss: 0.1233 - accuracy: 1.0000 - mse: 0.1233
# Epoch 353/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.1229 - accuracy: 1.0000 - mse: 0.1229
# Epoch 354/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.1224 - accuracy: 1.0000 - mse: 0.1224
# Epoch 355/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.1221 - accuracy: 1.0000 - mse: 0.1221
# Epoch 356/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.1217 - accuracy: 1.0000 - mse: 0.1217
# Epoch 357/512
# 4/4 [==============================] - 0s 708us/step - loss: 0.1213 - accuracy: 1.0000 - mse: 0.1213
# Epoch 358/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.1211 - accuracy: 1.0000 - mse: 0.1211
# Epoch 359/512
# 4/4 [==============================] - 0s 459us/step - loss: 0.1208 - accuracy: 1.0000 - mse: 0.1208
# Epoch 360/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.1202 - accuracy: 1.0000 - mse: 0.1202
# Epoch 361/512
# 4/4 [==============================] - 0s 550us/step - loss: 0.1222 - accuracy: 1.0000 - mse: 0.1222
# Epoch 362/512
# 4/4 [==============================] - 0s 463us/step - loss: 0.1197 - accuracy: 1.0000 - mse: 0.1197
# Epoch 363/512
# 4/4 [==============================] - 0s 712us/step - loss: 0.1214 - accuracy: 1.0000 - mse: 0.1214
# Epoch 364/512
# 4/4 [==============================] - 0s 493us/step - loss: 0.1209 - accuracy: 1.0000 - mse: 0.1209
# Epoch 365/512
# 4/4 [==============================] - 0s 435us/step - loss: 0.1188 - accuracy: 1.0000 - mse: 0.1188
# Epoch 366/512
# 4/4 [==============================] - 0s 435us/step - loss: 0.1182 - accuracy: 1.0000 - mse: 0.1182
# Epoch 367/512
# 4/4 [==============================] - 0s 545us/step - loss: 0.1200 - accuracy: 1.0000 - mse: 0.1200
# Epoch 368/512
# 4/4 [==============================] - 0s 558us/step - loss: 0.1177 - accuracy: 1.0000 - mse: 0.1177
# Epoch 369/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.1173 - accuracy: 1.0000 - mse: 0.1173
# Epoch 370/512
# 4/4 [==============================] - 0s 604us/step - loss: 0.1171 - accuracy: 1.0000 - mse: 0.1171
# Epoch 371/512
# 4/4 [==============================] - 0s 532us/step - loss: 0.1167 - accuracy: 1.0000 - mse: 0.1167
# Epoch 372/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.1162 - accuracy: 1.0000 - mse: 0.1162
# Epoch 373/512
# 4/4 [==============================] - 0s 604us/step - loss: 0.1160 - accuracy: 1.0000 - mse: 0.1160
# Epoch 374/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.1155 - accuracy: 1.0000 - mse: 0.1155
# Epoch 375/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.1152 - accuracy: 1.0000 - mse: 0.1152
# Epoch 376/512
# 4/4 [==============================] - 0s 423us/step - loss: 0.1150 - accuracy: 1.0000 - mse: 0.1150
# Epoch 377/512
# 4/4 [==============================] - 0s 557us/step - loss: 0.1145 - accuracy: 1.0000 - mse: 0.1145
# Epoch 378/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.1142 - accuracy: 1.0000 - mse: 0.1142
# Epoch 379/512
# 4/4 [==============================] - 0s 530us/step - loss: 0.1140 - accuracy: 1.0000 - mse: 0.1140
# Epoch 380/512
# 4/4 [==============================] - 0s 545us/step - loss: 0.1155 - accuracy: 1.0000 - mse: 0.1155
# Epoch 381/512
# 4/4 [==============================] - 0s 427us/step - loss: 0.1132 - accuracy: 1.0000 - mse: 0.1132
# Epoch 382/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.1146 - accuracy: 1.0000 - mse: 0.1146
# Epoch 383/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.1125 - accuracy: 1.0000 - mse: 0.1125
# Epoch 384/512
# 4/4 [==============================] - 0s 505us/step - loss: 0.1140 - accuracy: 1.0000 - mse: 0.1140
# Epoch 385/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.1119 - accuracy: 1.0000 - mse: 0.1119
# Epoch 386/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.1134 - accuracy: 1.0000 - mse: 0.1134
# Epoch 387/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.1111 - accuracy: 1.0000 - mse: 0.1111
# Epoch 388/512
# 4/4 [==============================] - 0s 571us/step - loss: 0.1127 - accuracy: 1.0000 - mse: 0.1127
# Epoch 389/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.1104 - accuracy: 1.0000 - mse: 0.1104
# Epoch 390/512
# 4/4 [==============================] - 0s 420us/step - loss: 0.1101 - accuracy: 1.0000 - mse: 0.1101
# Epoch 391/512
# 4/4 [==============================] - 0s 573us/step - loss: 0.1097 - accuracy: 1.0000 - mse: 0.1097
# Epoch 392/512
# 4/4 [==============================] - 0s 688us/step - loss: 0.1113 - accuracy: 1.0000 - mse: 0.1113
# Epoch 393/512
# 4/4 [==============================] - 0s 701us/step - loss: 0.1090 - accuracy: 1.0000 - mse: 0.1090
# Epoch 394/512
# 4/4 [==============================] - 0s 615us/step - loss: 0.1089 - accuracy: 1.0000 - mse: 0.1089
# Epoch 395/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.1083 - accuracy: 1.0000 - mse: 0.1083
# Epoch 396/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.1081 - accuracy: 1.0000 - mse: 0.1081
# Epoch 397/512
# 4/4 [==============================] - 0s 482us/step - loss: 0.1097 - accuracy: 1.0000 - mse: 0.1097
# Epoch 398/512
# 4/4 [==============================] - 0s 515us/step - loss: 0.1092 - accuracy: 1.0000 - mse: 0.1092
# Epoch 399/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.1070 - accuracy: 1.0000 - mse: 0.1070
# Epoch 400/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.1086 - accuracy: 1.0000 - mse: 0.1086
# Epoch 401/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.1082 - accuracy: 1.0000 - mse: 0.1082
# Epoch 402/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.1059 - accuracy: 1.0000 - mse: 0.1059
# Epoch 403/512
# 4/4 [==============================] - 0s 570us/step - loss: 0.1058 - accuracy: 1.0000 - mse: 0.1058
# Epoch 404/512
# 4/4 [==============================] - 0s 434us/step - loss: 0.1053 - accuracy: 1.0000 - mse: 0.1053
# Epoch 405/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.1068 - accuracy: 1.0000 - mse: 0.1068
# Epoch 406/512
# 4/4 [==============================] - 0s 504us/step - loss: 0.1048 - accuracy: 1.0000 - mse: 0.1048
# Epoch 407/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.1043 - accuracy: 1.0000 - mse: 0.1043
# Epoch 408/512
# 4/4 [==============================] - 0s 727us/step - loss: 0.1039 - accuracy: 1.0000 - mse: 0.1039
# Epoch 409/512
# 4/4 [==============================] - 0s 557us/step - loss: 0.1037 - accuracy: 1.0000 - mse: 0.1037
# Epoch 410/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.1035 - accuracy: 1.0000 - mse: 0.1035
# Epoch 411/512
# 4/4 [==============================] - 0s 424us/step - loss: 0.1031 - accuracy: 1.0000 - mse: 0.1031
# Epoch 412/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.1027 - accuracy: 1.0000 - mse: 0.1027
# Epoch 413/512
# 4/4 [==============================] - 0s 616us/step - loss: 0.1041 - accuracy: 1.0000 - mse: 0.1041
# Epoch 414/512
# 4/4 [==============================] - 0s 565us/step - loss: 0.1020 - accuracy: 1.0000 - mse: 0.1020
# Epoch 415/512
# 4/4 [==============================] - 0s 675us/step - loss: 0.1035 - accuracy: 1.0000 - mse: 0.1035
# Epoch 416/512
# 4/4 [==============================] - 0s 477us/step - loss: 0.1013 - accuracy: 1.0000 - mse: 0.1013
# Epoch 417/512
# 4/4 [==============================] - 0s 431us/step - loss: 0.1010 - accuracy: 1.0000 - mse: 0.1010
# Epoch 418/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.1008 - accuracy: 1.0000 - mse: 0.1008
# Epoch 419/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.1003 - accuracy: 1.0000 - mse: 0.1003
# Epoch 420/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.1018 - accuracy: 1.0000 - mse: 0.1018
# Epoch 421/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.0997 - accuracy: 1.0000 - mse: 0.0997
# Epoch 422/512
# 4/4 [==============================] - 0s 682us/step - loss: 0.0995 - accuracy: 1.0000 - mse: 0.0995
# Epoch 423/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.0991 - accuracy: 1.0000 - mse: 0.0991
# Epoch 424/512
# 4/4 [==============================] - 0s 423us/step - loss: 0.1004 - accuracy: 1.0000 - mse: 0.1004
# Epoch 425/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.0983 - accuracy: 1.0000 - mse: 0.0983
# Epoch 426/512
# 4/4 [==============================] - 0s 470us/step - loss: 0.0979 - accuracy: 1.0000 - mse: 0.0979
# Epoch 427/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.0995 - accuracy: 1.0000 - mse: 0.0995
# Epoch 428/512
# 4/4 [==============================] - 0s 529us/step - loss: 0.0975 - accuracy: 1.0000 - mse: 0.0975
# Epoch 429/512
# 4/4 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 1.0000 - mse: 0.08 - 0s 599us/step - loss: 0.0987 - accuracy: 1.0000 - mse: 0.0987
# Epoch 430/512
# 4/4 [==============================] - 0s 806us/step - loss: 0.0982 - accuracy: 1.0000 - mse: 0.0982
# Epoch 431/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.0981 - accuracy: 1.0000 - mse: 0.0981
# Epoch 432/512
# 4/4 [==============================] - 0s 432us/step - loss: 0.0962 - accuracy: 1.0000 - mse: 0.0962
# Epoch 433/512
# 4/4 [==============================] - 0s 419us/step - loss: 0.0957 - accuracy: 1.0000 - mse: 0.0957
# Epoch 434/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.0955 - accuracy: 1.0000 - mse: 0.0955
# Epoch 435/512
# 4/4 [==============================] - 0s 427us/step - loss: 0.0952 - accuracy: 1.0000 - mse: 0.0952
# Epoch 436/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.0964 - accuracy: 1.0000 - mse: 0.0964
# Epoch 437/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.0944 - accuracy: 1.0000 - mse: 0.0944
# Epoch 438/512
# 4/4 [==============================] - 0s 686us/step - loss: 0.0942 - accuracy: 1.0000 - mse: 0.0942
# Epoch 439/512
# 4/4 [==============================] - 0s 759us/step - loss: 0.0937 - accuracy: 1.0000 - mse: 0.0937
# Epoch 440/512
# 4/4 [==============================] - 0s 533us/step - loss: 0.0950 - accuracy: 1.0000 - mse: 0.0950
# Epoch 441/512
# 4/4 [==============================] - 0s 463us/step - loss: 0.0931 - accuracy: 1.0000 - mse: 0.0931
# Epoch 442/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.0928 - accuracy: 1.0000 - mse: 0.0928
# Epoch 443/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.0925 - accuracy: 1.0000 - mse: 0.0925
# Epoch 444/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.0938 - accuracy: 1.0000 - mse: 0.0938
# Epoch 445/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.0918 - accuracy: 1.0000 - mse: 0.0918
# Epoch 446/512
# 4/4 [==============================] - 0s 585us/step - loss: 0.0916 - accuracy: 1.0000 - mse: 0.0916
# Epoch 447/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.0914 - accuracy: 1.0000 - mse: 0.0914
# Epoch 448/512
# 4/4 [==============================] - 0s 563us/step - loss: 0.0909 - accuracy: 1.0000 - mse: 0.0909
# Epoch 449/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.0908 - accuracy: 1.0000 - mse: 0.0908
# Epoch 450/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0918 - accuracy: 1.0000 - mse: 0.0918
# Epoch 451/512
# 4/4 [==============================] - 0s 600us/step - loss: 0.0916 - accuracy: 1.0000 - mse: 0.0916
# Epoch 452/512
# 4/4 [==============================] - 0s 628us/step - loss: 0.0898 - accuracy: 1.0000 - mse: 0.0898
# Epoch 453/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.0896 - accuracy: 1.0000 - mse: 0.0896
# Epoch 454/512
# 4/4 [==============================] - 0s 505us/step - loss: 0.0907 - accuracy: 1.0000 - mse: 0.0907
# Epoch 455/512
# 4/4 [==============================] - 0s 511us/step - loss: 0.0888 - accuracy: 1.0000 - mse: 0.0888
# Epoch 456/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.0887 - accuracy: 1.0000 - mse: 0.0887
# Epoch 457/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.0884 - accuracy: 1.0000 - mse: 0.0884
# Epoch 458/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.0879 - accuracy: 1.0000 - mse: 0.0879
# Epoch 459/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.0892 - accuracy: 1.0000 - mse: 0.0892
# Epoch 460/512
# 4/4 [==============================] - 0s 618us/step - loss: 0.0874 - accuracy: 1.0000 - mse: 0.0874
# Epoch 461/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.0871 - accuracy: 1.0000 - mse: 0.0871
# Epoch 462/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.0882 - accuracy: 1.0000 - mse: 0.0882
# Epoch 463/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0878 - accuracy: 1.0000 - mse: 0.0878
# Epoch 464/512
# 4/4 [==============================] - 0s 463us/step - loss: 0.0861 - accuracy: 1.0000 - mse: 0.0861
# Epoch 465/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.0873 - accuracy: 1.0000 - mse: 0.0873
# Epoch 466/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.0857 - accuracy: 1.0000 - mse: 0.0857
# Epoch 467/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.0865 - accuracy: 1.0000 - mse: 0.0865
# Epoch 468/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.0851 - accuracy: 1.0000 - mse: 0.0851
# Epoch 469/512
# 4/4 [==============================] - 0s 737us/step - loss: 0.0848 - accuracy: 1.0000 - mse: 0.0848
# Epoch 470/512
# 4/4 [==============================] - 0s 607us/step - loss: 0.0856 - accuracy: 1.0000 - mse: 0.0856
# Epoch 471/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.0842 - accuracy: 1.0000 - mse: 0.0842
# Epoch 472/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.0839 - accuracy: 1.0000 - mse: 0.0839
# Epoch 473/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.0849 - accuracy: 1.0000 - mse: 0.0849
# Epoch 474/512
# 4/4 [==============================] - 0s 419us/step - loss: 0.0833 - accuracy: 1.0000 - mse: 0.0833
# Epoch 475/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.0830 - accuracy: 1.0000 - mse: 0.0830
# Epoch 476/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.0825 - accuracy: 1.0000 - mse: 0.0825
# Epoch 477/512
# 4/4 [==============================] - 0s 676us/step - loss: 0.0823 - accuracy: 1.0000 - mse: 0.0823
# Epoch 478/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.0822 - accuracy: 1.0000 - mse: 0.0822
# Epoch 479/512
# 4/4 [==============================] - 0s 587us/step - loss: 0.0817 - accuracy: 1.0000 - mse: 0.0817
# Epoch 480/512
# 4/4 [==============================] - 0s 533us/step - loss: 0.0828 - accuracy: 1.0000 - mse: 0.0828
# Epoch 481/512
# 4/4 [==============================] - 0s 466us/step - loss: 0.0825 - accuracy: 1.0000 - mse: 0.0825
# Epoch 482/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.0810 - accuracy: 1.0000 - mse: 0.0810
# Epoch 483/512
# 4/4 [==============================] - 0s 428us/step - loss: 0.0807 - accuracy: 1.0000 - mse: 0.0807
# Epoch 484/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.0816 - accuracy: 1.0000 - mse: 0.0816
# Epoch 485/512
# 4/4 [==============================] - 0s 530us/step - loss: 0.0801 - accuracy: 1.0000 - mse: 0.0801
# Epoch 486/512
# 4/4 [==============================] - 0s 647us/step - loss: 0.0808 - accuracy: 1.0000 - mse: 0.0808
# Epoch 487/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.0794 - accuracy: 1.0000 - mse: 0.0794
# Epoch 488/512
# 4/4 [==============================] - 0s 753us/step - loss: 0.0805 - accuracy: 1.0000 - mse: 0.0805
# Epoch 489/512
# 4/4 [==============================] - 0s 564us/step - loss: 0.0789 - accuracy: 1.0000 - mse: 0.0789
# Epoch 490/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.0785 - accuracy: 1.0000 - mse: 0.0785
# Epoch 491/512
# 4/4 [==============================] - 0s 806us/step - loss: 0.0797 - accuracy: 1.0000 - mse: 0.0797
# Epoch 492/512
# 4/4 [==============================] - 0s 443us/step - loss: 0.0793 - accuracy: 1.0000 - mse: 0.0793
# Epoch 493/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.0788 - accuracy: 1.0000 - mse: 0.0788
# Epoch 494/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.0788 - accuracy: 1.0000 - mse: 0.0788
# Epoch 495/512
# 4/4 [==============================] - 0s 712us/step - loss: 0.0784 - accuracy: 1.0000 - mse: 0.0784
# Epoch 496/512
# 4/4 [==============================] - 0s 429us/step - loss: 0.0768 - accuracy: 1.0000 - mse: 0.0768
# Epoch 497/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.0779 - accuracy: 1.0000 - mse: 0.0779
# Epoch 498/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.0777 - accuracy: 1.0000 - mse: 0.0777
# Epoch 499/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.0773 - accuracy: 1.0000 - mse: 0.0773
# Epoch 500/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.0757 - accuracy: 1.0000 - mse: 0.0757
# Epoch 501/512
# 4/4 [==============================] - 0s 484us/step - loss: 0.0767 - accuracy: 1.0000 - mse: 0.0767
# Epoch 502/512
# 4/4 [==============================] - 0s 439us/step - loss: 0.0751 - accuracy: 1.0000 - mse: 0.0751
# Epoch 503/512
# 4/4 [==============================] - 0s 553us/step - loss: 0.0749 - accuracy: 1.0000 - mse: 0.0749
# Epoch 504/512
# 4/4 [==============================] - 0s 573us/step - loss: 0.0747 - accuracy: 1.0000 - mse: 0.0747
# Epoch 505/512
# 4/4 [==============================] - 0s 570us/step - loss: 0.0742 - accuracy: 1.0000 - mse: 0.0742
# Epoch 506/512
# 4/4 [==============================] - 0s 699us/step - loss: 0.0741 - accuracy: 1.0000 - mse: 0.0741
# Epoch 507/512
# 4/4 [==============================] - 0s 672us/step - loss: 0.0737 - accuracy: 1.0000 - mse: 0.0737
# Epoch 508/512
# 4/4 [==============================] - 0s 533us/step - loss: 0.0748 - accuracy: 1.0000 - mse: 0.0748
# Epoch 509/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0733 - accuracy: 1.0000 - mse: 0.0733
# Epoch 510/512
# 4/4 [==============================] - 0s 641us/step - loss: 0.0730 - accuracy: 1.0000 - mse: 0.0730
# Epoch 511/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0726 - accuracy: 1.0000 - mse: 0.0726
# Epoch 512/512
# 4/4 [==============================] - 0s 440us/step - loss: 0.0737 - accuracy: 1.0000 - mse: 0.0737

# %% [markdown]
# Note above that we've made it easy to vary the number of epochs.  This is worth exploring after we first cover some basics starting with tools to summarize the model fitting process.
#
# To start, ```summary``` will give an overview of the network, including how many parameters are used.  The ```None``` in the Output Shape column corresponds to the number of input values fed through the network.  ```summary``` must be called *after* ```fit```.

# %%
network1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# If we want to inspect where the weights are stored in a network we can use the ```_layers``` attribute of the network:

# %%
network1._layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7fa0802e36d0>,
#  <keras.layers.core.Dense at 0x7fa0c052a650>,
#  <keras.layers.core.Dense at 0x7fa0c052a610>]

# %% [markdown]
# Each of the elements in this list represents the things associated with one of the layers of the network.  The ```InputLayer``` doesn't actually interest us (it deals with reading in data), but we can look at the weights of the hidden layer:

# %%
foo = network1._layers[1].weights
foo
# Out:
# [<tf.Variable 'dense_3/kernel:0' shape=(2, 10) dtype=float32>,
#  <tf.Variable 'dense_3/bias:0' shape=(10,) dtype=float32>]

# %% [markdown]
# But it is **important** to take a moment and realize these weights are more than just a numpy array.  Seen as displayed above they are a data structre that came into existence when the network was compiled. But, they actually only have weight values after fitting.  And here is how you can examine (after fitting) the weights themselves.

# %%
foo = network1._layers[1].get_weights()
foo
# Out:
# [array([[ 0.31126457,  0.3293616 , -0.4792375 , -0.5117767 , -0.11759377,
#           0.00202607,  0.30739135, -0.43684414,  0.4696192 , -0.56932634],
#         [ 0.26156136,  0.6287924 ,  0.47059697, -0.08896871, -0.11735523,
#           0.12018564, -0.23469537,  0.54106677, -0.45052817, -0.5352695 ]],
#        dtype=float32),
#  array([ 8.82230233e-06,  9.36439484e-02, -5.35134983e-04,  8.91713202e-02,
#          0.00000000e+00, -1.27979770e-01, -7.22767264e-02, -1.04684874e-01,
#         -1.81963108e-02,  0.00000000e+00], dtype=float32)]

# %% [markdown]
# and the output layer:

# %%
print(network1._layers[2].get_weights())
# Out:
# [array([[ 0.5971247 ],
#        [-1.0142235 ],
#        [ 0.9235966 ],
#        [ 0.5007663 ],
#        [-0.34412697],
#        [ 0.66132444],
#        [-0.28613004],
#        [ 0.25106627],
#        [ 0.45223927],
#        [-0.25158274]], dtype=float32), array([0.28980562], dtype=float32)]

# %% [markdown]
# We can also use the network for prediction:

# %%
print(X_xor)
print(network1.predict(X_xor))
# Out:
# [[0. 0.]
#  [1. 0.]
#  [0. 1.]
#  [1. 1.]]
# [[0.70415133]
#  [0.21590015]
#  [0.3259517 ]
#  [0.7239853 ]]

# %% [markdown]
# Remember that the network is trying to approximate the values [1, 0, 0, 1].  Let's look at the history of the loss and accuracy over the epochs of training the network using the ```history``` of the trained network:

# %%
plt.plot(history1.history['accuracy'], label='Accuracy')
plt.plot(history1.history['mse'], label='MSE')
plt.ylim([0, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# Let's also look at the decision surface of this network:

# %%
plot_XOR_network(network1)

# %% [markdown]
# We can also add more layers and have more nodes in each layer:

# %%
network2 = keras.Sequential()
network2.add(keras.layers.Dense(50, activation='relu'))
network2.add(keras.layers.Dense(25, activation='relu'))
network2.add(keras.layers.Dense(12, activation='relu'))
network2.add(keras.layers.Dense(1))

loss_fn = keras.losses.MeanSquaredError()
opt = keras.optimizers.SGD(learning_rate=0.005)
network2.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

history2 = network2.fit(X_xor, y_xor, batch_size=2, epochs=512, verbose=0)

# %%
network2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 50)                150
# _________________________________________________________________
# dense_6 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_7 (Dense)              (None, 12)                312
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 1,750
# Trainable params: 1,750
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This model has far more complexity than is necessary for this problem - a total of 1,750 parameters is orders of magnitude larger than necessary, but it still finds a good solution.

# %%
plt.plot(history2.history['accuracy'], label='Accuracy')
plt.plot(history2.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %%
plot_XOR_network(network2)

# %% [markdown]
# ## One hot encoding, Softmax and the Loss Function

# %% [markdown]
# ## One hot encoding
#
# Using the Euclidean distance of the outputs from the true values probably isn't the best loss function to be using: it is designed for regression problems. Instead, we can use the cross entropy loss (yes we are introducing a new term which will be defined shortly).  To do this, one thing we need to do is change our expected outputs from being 0 or 1 to be "one-hot-encoded:"

# %%
y_xor_one_hot = keras.utils.to_categorical(y_xor, 2)

for a,b in zip(y_xor, y_xor_one_hot) :
    print(f'y value {a} maps to the encoding {b}')
# Out:
# y value 1 maps to the encoding [0. 1.]
# y value 0 maps to the encoding [1. 0.]
# y value 0 maps to the encoding [1. 0.]
# y value 1 maps to the encoding [0. 1.]

# %% [markdown]
# In one-hot-encoding, each output is now a vector with zero at each class label that is not correct for the associated input and one at the class label that is correct.  One thing to note with this modification is that our network will now have two outputs.
#
# It's also useful to restrict the outputs of our network to look like probabilities.  One way to do this would be to normalize the outputs to be
# \begin{align*}
# z_1' &= \frac{z_1}{z_1 + z_2} \\
# z_2' &= \frac{z_2}{z_1 + z_2}
# \end{align*}
# which gives us $z_1'$ and $z_2'$ values each between zero and one and summing to one.  One thing to keep in mind here is that although these now form a probability distribution, it isn't necessarily accurate to view $z_1'$ as the "probability that the input is of class one" because the approximation given by our network is just that - an approximation. While useful from a pracitcal standpoint it should not be confused with a rigorously established estimate of the true underlying probability.
#
#
# Another way to do this would be to take the hard max of the outputs,
# \begin{align*}
# z_1' &= \begin{cases} 1 & z_1 \geq z_2 \\ 0 & z_1 < z_2 \end{cases} \\
# z_2' &= \begin{cases} 0 & z_1 \geq z_2 \\ 1 & z_1 < z_2 \end{cases},
# \end{align*}
# which has similar nice properties but is unfortunately not differentiable, so we can't actually use it for classification.
#
# A compromise between these two is softmax.  For our two raw outputs, $z_1$ and $z_2$, the softmax activation function is calculated as
# \begin{align*}
# \text{softmax}(z_1) &= \frac{e^{z_1}}{e^{z_1} + e^{z_2}} \\
# \text{softmax}(z_2) &= \frac{e^{z_2}}{e^{z_1} + e^{z_2}}
# \end{align*}
#
# This is very similar to normalization, but with the exponential function of the raw inputs instead.  This means that values will behave in a manner similar to the softwax while maintaining differentiability.

# %% [markdown]
# ### Visualizing Softmax
#
# Here is a simple bit of code to help you visualize what happens when a set of activations on the last layer of a classification network are run through the softmax function.

# %%
def apply_softmax(acts) :
    exp_acts = np.array([np.exp(x) for x in acts])
    exp_acts_sum = np.sum(exp_acts)
    acts_smax = np.array([np.exp(x)/exp_acts_sum for x in acts])
    return exp_acts, acts_smax

def visualize_softmax(mean, sigma, nsamples, rseed) :
    rng = default_rng(rseed)
    act = rng.normal(mean, sigma, nsamples)
    aex, asf = apply_softmax(act)
    plt.style.use('seaborn-deep')
    fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(13,5))
    ax1.bar(range(nsamples), act, color='darkred')
    ax1.set_xlabel('Output Node')
    ax1.set_ylabel('Activation')
    ax1.set_title('Input Activations')   
    ax2.bar(range(nsamples), aex, color='darkblue')
    ax2.set_xlabel('Output Node')
    ax2.set_ylabel('After Exponentiation')
    ax2.set_title('Exponentiated Input Activation')  
    ax3.bar(range(nsamples), asf, color='darkgreen')
    ax3.set_xlabel('Output Node')
    ax3.set_ylabel('Activation')
    ax3.set_title('Softmax applied to Activations')
    
    plt.show()

# %%
rseed = np.random.randint(0,99)
visualize_softmax(5, 1.0, 8, rseed)
print(f'Random seed is: {rseed}')
# Out:
# Random seed is: 87

# %% [markdown]
# ### XOR and a One Hot Softmax Output
#
# Our third network still solves XOR but with the one hot encoding and softmax just introduced. Also, the loss function is now Cross Entropy.

# %%
network3 = keras.Sequential()
network3.add(keras.layers.Dense(10, activation='relu'))
network3.add(keras.layers.Dense(2, activation='softmax'))

loss_fn = keras.losses.BinaryCrossentropy()
opt     = keras.optimizers.SGD(learning_rate=0.01)
network3.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %%
history3 = network3.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=600, verbose=0)
# Out:
# WARNING:tensorflow:From /Users/ross/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
plt.plot(history3.history['accuracy'], label='Accuracy')
plt.plot(history3.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# To visualize the decision surface, we will plot $z_1 - z_2$.  This is a trick we will use throughout the rest of the notebook.

# %%
plot_XOR_network(network3, two_outputs=True)

# %% [markdown]
# ## Nonconvex Optimization

# %% [markdown]
# For linear models, finding a solution that minimizes some quantity of interest was relatively easy because the error surface has a single global minimum.  Whenever the error function satisfies a certain condition known as "convexity", this is guaranteed to be the case.
# Here's an example of a loss surface of a convex problem:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2)
points = np.r_[True, y[1:] <= y[:-1]] & np.r_[y[:-1] <= y[1:], True]
plt.plot(x, y, label='Loss Surface')
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.title("Convex Optimization")
plt.xticks([])
plt.yticks([])
plt.scatter(x[points], y[points], c='r', label='minimum')
plt.legend();

# %% [markdown]
# As we change the weights of the model, we move around on the blue curve.  The goal is to find a configuration of weights that places us at the location of the red dot, which is the minimum of this function.

# %% [markdown]
# However, due to the nonlinearity of neural networks, there may be more than one minimum.  For example:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2) + 5*np.sin(np.pi*x)
points = np.r_[True, y[1:] < y[:-1]] & np.r_[y[:-1] < y[1:], True]
plt.plot(x, y, label="Loss Surface")
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.xticks([])
plt.yticks([])
plt.title("Nonconvex Optimization")
plt.scatter(x[points], y[points], c='r', label='minima')
plt.legend();

# %% [markdown]
# In this case, there is a single global minimum that represents the optimal solution, but there are a number of other *local* minima.
#
# Gradient descent and many of its variants are the most commonly used algorithms for optimizing the weights of neural networks.  Gradient descent can be thought of as behaving like a ball that is placed on the the loss surface - it rolls down hills.  That means that if an initial configuration of a neural network lies somewhere in a valley around one of the local minima, gradient descent will push it towards that local minimum rather than the global minimum.
# However, that may or may not be a problem!  We are interested in solutions that have high prediction accuracy - not necessarily finding the global minimum.

# %% [markdown]
# ## Gradient Descent Modifications and Regularization

# %% [markdown]
# The simple SGD algorithm has a modification that can help with shallow local minima and plateaus in the loss surface - momentum.  Intuitively, this is the same as the idea would be in physics, where the model builds momentum as it travels, and can continue to follow that momentum rather than just going in the direction of most change.  This helps avoid shallow local minima and can prevent the model from slowing down too much on plateaus.

# %%
opt = keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)

# %% [markdown]
# We can also add weight decay to our model, where weights are driven towards small values to reduce the likelihood of overfitting and smooth the loss surface:

# %%
# Pointless Comment

reg = keras.regularizers.l2(1e-4)
network4 = keras.Sequential()
network4.add(keras.layers.Dense(10, activation='relu', kernel_regularizer=reg, bias_regularizer=reg))
network4.add(keras.layers.Dense(2, activation='softmax', kernel_regularizer=reg, bias_regularizer=reg))

# %% [markdown]
# The rest of our setup is the same as it has been previously.

# %%
loss_fn = keras.losses.BinaryCrossentropy()

network4.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %%
history4 = network4.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=100, verbose=0)

# %%
plt.plot(history4.history['accuracy'], label='Accuracy')
plt.plot(history4.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# This network trains *much* faster than the previous models.  While testing this notebook, the model frequently achieved zero loss by epoch 50.

# %%
plot_XOR_network(network4, two_outputs=True)

# %% [markdown]
# There are also more complex optimizers, such as the [Adam optimizer](https://arxiv.org/pdf/1412.6980.pdf) designed by Diederik Kingma and Jimmy Ba.  It uses a variety of techniques like adaptive learning rates and momentums to provide competitive performance.  To use it in Keras, call it as

# %%
opt = keras.optimizers.Adam()

# %% [markdown]
# It has default parameters that empirically work well on a wide class of problems.

# %% [markdown]
# ## Complex Problems

# %% [markdown]
# [Neural Networks, Manifolds, and Topology](https://colah.github.io/posts/2014-03-NN-Manifolds-Topology/) by Christopher Olah has animated versions for $\tanh$ networks of some of the investigations and examples shown here.

# %% [markdown]
# Now let's consider a slightly more difficult problem for neural networks:

# %%
r1 = 0.5
r2 = np.sqrt(2*r1**2)
r3 = np.sqrt(r1**2 + r2**2)

fig = plt.figure()
ax = fig.add_subplot(111)

circle = plt.Circle((0, 0), r1)
annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, color='r')
ax.add_artist(circle)
ax.add_artist(annulus)
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# By itself this is a relatively easy problem - if we convert to polar coordinates, we can just threshold based on the radius and have a very simple classifier that achieves 100% accuracy.  However, if we use the raw $x_1$ and $x_2$ inputs to a neural network, that information must be learned by the network.  The network must be able to construct a closed region in the plane, which requires more complexity than was necessary for XOR.
#
# For training a network we need specific inputs, so we will get 500 points from the circle and 500 from the annulus with their associated class labels:

# %%
X_circle = []
y_circle = []
for i in range(500):
    # Circle
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) > r1:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(0)
        
    # Annulus
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) < r2 or np.linalg.norm(vec) > r3:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(1)
    
X_circle = np.array(X_circle)
X_circle = X_circle.astype('float32')
y_circle = np.array(y_circle)
y_circle_one_hot = keras.utils.to_categorical(y_circle, 2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X_circle[y_circle==0, 0], X_circle[y_circle==0, 1])
ax.scatter(X_circle[y_circle==1, 0], X_circle[y_circle==1, 1], c='r')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# Let's train a simple network on this and keep trying until we make sure we get a better solution than random:

# %%
while True:
    network5 = keras.Sequential()
    network5.add(keras.layers.Dense(2, activation='relu'))
    network5.add(keras.layers.Dense(2, activation='softmax'))

    loss_fn = keras.losses.BinaryCrossentropy()
    opt = keras.optimizers.Adam()
    network5.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    
    history5 = network5.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    print('Trained one network to {} accuracy'.format(history5.history['accuracy'][-1]))
    if history5.history['accuracy'][-1] > 0.78:
        break
# Out:
# Trained one network to 0.6639999747276306 accuracy
# Trained one network to 0.640999972820282 accuracy
# Trained one network to 0.7910000085830688 accuracy

# %%
plt.plot(history5.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network5, two_outputs=True)

# %% [markdown]
# **Comment/Warning** - the next three paragraphs describe one possible solution, not necessarily the one you are seeing. This is because the network - each time it is trained - finds somewhat different solutions.
#
# This network gets about 80% accuracy, which is somewhat close to the best that can be expected from this architecture.  Let's look at what it actually does to the data.  The first thing it does is apply the weights of the first layer to transform the data:

# %% [markdown]
# Every data point with a horizontal coordinate below zero has its horizontal coordinate taken to zero - effectively shoving all the negative data to zero on that axis.
#
# We can do the same thing with the second node, which is the vertical axis:

# %% [markdown]
# This doesn't look particularly useful, but notice that all of the blue data points are in the lower left corner.  That means that when the decision boundary is drawn on, they can (mostly) be on one side, even if there is significant mixing with the red points.
#
# That decision boundary comes from the hidden to output weights, as that is the linear classifier the network is using.  In the new space created by applying the first layer, the decision boundary is a straight line:

# %% [markdown]
# Now let's train a network that solves this, with three nodes in its hidden layer.  We may have to train it multiple times for it to find a solution with 100% accuracy.

# %%
while True:
    network6 = keras.Sequential()
    network6.add(keras.layers.Dense(3, activation='relu'))
    network6.add(keras.layers.Dense(2, activation='softmax'))

    loss_fn = keras.losses.BinaryCrossentropy()
    opt = keras.optimizers.Adam()
    network6.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    history6 = network6.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    
    print('Trained one network to {} accuracy'.format(history6.history['accuracy'][-1]))
    if history6.history['accuracy'][-1] >= 0.996:
        break
# Out:
# Trained one network to 0.6669999957084656 accuracy
# Trained one network to 0.640999972820282 accuracy
# Trained one network to 0.9940000176429749 accuracy
# Trained one network to 0.9980000257492065 accuracy

# %%
plt.plot(history6.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network6, two_outputs=True)

# %% [markdown]
# This should have perfect or near perfect accuracy on the data we are considering - if it is perfect, it likely has a hexagonal shape, and if it is imperfect it has like found a square shape with the corners overlapping the annulus.

# %% [markdown]
# ## Comments
#
# 1. Some of the intuition from these small, two-input networks may not carry over in expected ways to higher dimensional problems.  Unfortunately, building intuition for those more complex problems is typically difficult due to the limited ability to analyze high dimensional networks.  We will discuss more complex problems in our next notebook.
# 2. Until relatively recently, one of the best methods for hyperparameter selection with neural networks was random search.  More sophisticated methods exist now, but without insight into the dataset it can be difficult to determine how to structure network architecture and training process
# 3. Keras used to be independent from the chosen backend, but its creator now works for Google (the makers of TensorFlow), and backends like PyTorch are no longer being updated, so the "recommended" backend is TensorFlow.  Keras is also being more closely tied into TensorFlow.
