# %% [markdown]
# # Neural Networs and Keras
#
# This notebook is part of  course materials for CS 345: Machine Learning Foundations and Practice at Colorado State University.
# Original versions were created by Ben Sattelberg and Asa Ben-Hur with updates by Ross Beveridge.
#
# Last Update 4/19/2022
#
#
# *The text is released under the [CC BY-SA license](https://creativecommons.org/licenses/by-sa/4.0/), and code is released under the [MIT license](https://opensource.org/licenses/MIT).*

# %% [markdown]
# # Neural Networks

# %%
# %matplotlib inline
import numpy as np
from numpy.random import default_rng

import matplotlib.pyplot as plt
import matplotlib

from IPython import display
from base64 import b64decode

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import keras

import tensorflow as tf
#tf.compat.v1.enable_eager_execution()
tf.executing_eagerly()
# Out:
# Using TensorFlow backend.
# False

# %% [markdown]
# ### Plotting functionality for later

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_XOR_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')

    delta = 0.01
    xmin=-0.1;xmax=1.1;ymin=-0.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-1, vmax=1)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    X = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
    y = np.array([1, 0, 0, 1])

    plt.style.use('default')
    ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()

#     ax2.plot_wireframe(x_grid, y_grid, Z, alpha=0.5);
#     ax2.scatter(X[:,0], X[:,1], y, c=y, alpha=1, s=20, cmap='bwr')

#     ax2.set_xlabel('$x_1$')
#     ax2.set_ylabel('$x_2$')
#     ax2.set_zlabel('f($x_1$, $x_2$)');

# %%
def plot_circles_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')
    
    r1 = 0.5
    r2 = np.sqrt(2*r1**2)
    r3 = np.sqrt(r1**2 + r2**2)

    delta = 0.01
    xmin=-1.1;xmax=1.1;ymin=-1.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-0.001, vmax=0.001)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    plt.style.use('default')
    #ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()
    
    circle = plt.Circle((0, 0), r1, alpha=0.5, edgecolor='k')
    annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, facecolor='r', alpha=0.5, edgecolor='k')
    ax.add_artist(circle)
    ax.add_artist(annulus)

# %% [markdown]
# ## Introduction to Keras

# %% [markdown]
# Last time we introduced neural networks and built a simple architecture we could use to (sometimes) solve the XOR problem.  We saw the challenge of programming a network with increasing numbers of units and layers.
#
# Fortunately, there exist a number of packages designed for neural networks use that automatically determine the correct update rules with backpropagation.  A few of the packages that are used in CSU's CS department are [TensorFlow](https://www.tensorflow.org), [PyTorch](https://pytorch.org), and [Keras](https://keras.io).  These packages use Python despite the fact that Python may be relatively slow compared to compiled languages.  These deep learning packages often compile their code into those faster languages or are able to take advantage of optimizations that give competitive performance.
#
# We'll use Keras with a TensorFlow backend as it is simple to use and competitive with other options.

# %% [markdown]
# The [Keras website](https://keras.io/) has good tutorials and documentation.

# %% [markdown]
# First, we will create our dataset - the same XOR problem discussed in the previous notebook.  The only difference is that we convert the input values to be 32 bit floating point values, rather than 64 bit.  This isn't strictly necessary, but most neural network packages use 32 bit floats because the added precision is not worth the memory and computational cost.

# %%
X_xor = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
y_xor = np.array([1, 0, 0, 1])

X_xor = X_xor.astype('float32')

# %% [markdown]
# Now we can set up a network.  We will use a ```Sequential``` network, which is the container for a multilayer perceptron/feedforward neural network structure. Keep in mind this is exactly the general type of network introduced in the multi-layer perceptron buildt from scratch earlier.

# %%
network1 = keras.Sequential()

# %% [markdown]
# Now we can add layers to it.  The first layer we add is our hidden layer.  Having two nodes would give us a network which *can* work, but frequently doesn't, so let's create a much larger network with ten nodes in its hidden layer.  This is referred to as a ```Dense``` layer, as every input has a weight connecting it to every node in the previous layer.  We also tell Keras to use the ReLU activation function for it.
#
# Finally, we will add a layer that transforms the outputs of the hidden layer into the single output value.  By not passing an activation function in, this defaults to having no activation function.

# %%
network1.add(keras.layers.Dense(10, activation='relu'))
network1.add(keras.layers.Dense(1))

# %% [markdown]
# This sets up a network that looks like this:

# %%
# Code here just allows image to be contained within this file
bar = '...'
display.Image(b64decode(bar),width=800)

# %% [markdown]
# Given the network, we can now set up the training process.  We will use the mean squared error as the loss function and use stochastic gradient descent as the optimzer:

# %%
loss_fn = keras.losses.MeanSquaredError()
opt     = keras.optimizers.SGD(learning_rate=0.005)

# %% [markdown]
# The command ```network.compile(...)``` constructs the network as something that can be trained or evaluated.  The ```metrics``` parameter accepts a list of values that we want to keep track of during the training process.

# %%
network1.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %% [markdown]
# With all of the set up out of the way, we are ready to train the network.  The ```batch_size``` controls how many inputs to pass through the network at a time.   With traditional gradient descent it would be every input and with traditional stochastic gradient descent it would be a single input.  The ```verbose``` parameter controls to what extent the network prints output reflecting its progress.  Notice that it keeps track of the loss used for training, and the 'accuracy' and 'mse' values that we passed as metrics of interest.  In this case the loss is MSE, so the two values are the same.

# %%
# n_epochs = 512
n_epochs = 512
history1 = network1.fit(X_xor, y_xor, batch_size=2, epochs=n_epochs, verbose=1)
# Out:
# WARNING:tensorflow:From /Users/ross/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/512
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3626 - accuracy: 0.5000 - mse: 0.3626
# Epoch 2/512
# 4/4 [==============================] - 0s 631us/step - loss: 0.3603 - accuracy: 0.5000 - mse: 0.3603
# Epoch 3/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.3546 - accuracy: 0.5000 - mse: 0.3546
# Epoch 4/512
# 4/4 [==============================] - 0s 509us/step - loss: 0.3524 - accuracy: 0.5000 - mse: 0.3524
# Epoch 5/512
# 4/4 [==============================] - 0s 436us/step - loss: 0.3498 - accuracy: 0.5000 - mse: 0.3498
# Epoch 6/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.3475 - accuracy: 0.5000 - mse: 0.3475
# Epoch 7/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.3457 - accuracy: 0.5000 - mse: 0.3457
# Epoch 8/512
# 4/4 [==============================] - 0s 621us/step - loss: 0.3434 - accuracy: 0.5000 - mse: 0.3434
# Epoch 9/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.3411 - accuracy: 0.5000 - mse: 0.3411
# Epoch 10/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.3389 - accuracy: 0.5000 - mse: 0.3389
# Epoch 11/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.3369 - accuracy: 0.5000 - mse: 0.3369
# Epoch 12/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.3346 - accuracy: 0.5000 - mse: 0.3346
# Epoch 13/512
# 4/4 [==============================] - 0s 585us/step - loss: 0.3355 - accuracy: 0.5000 - mse: 0.3355
# Epoch 14/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.3334 - accuracy: 0.5000 - mse: 0.3334
# Epoch 15/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.3286 - accuracy: 0.5000 - mse: 0.3286
# Epoch 16/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.3266 - accuracy: 0.5000 - mse: 0.3266
# Epoch 17/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.3246 - accuracy: 0.5000 - mse: 0.3246
# Epoch 18/512
# 4/4 [==============================] - 0s 516us/step - loss: 0.3226 - accuracy: 0.5000 - mse: 0.3226
# Epoch 19/512
# 4/4 [==============================] - 0s 529us/step - loss: 0.3203 - accuracy: 0.5000 - mse: 0.3203
# Epoch 20/512
# 4/4 [==============================] - 0s 556us/step - loss: 0.3189 - accuracy: 0.5000 - mse: 0.3189
# Epoch 21/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.3194 - accuracy: 0.5000 - mse: 0.3194
# Epoch 22/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.3177 - accuracy: 0.5000 - mse: 0.3177
# Epoch 23/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.3128 - accuracy: 0.7500 - mse: 0.3128
# Epoch 24/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.3140 - accuracy: 0.5000 - mse: 0.3140
# Epoch 25/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.3096 - accuracy: 0.7500 - mse: 0.3096
# Epoch 26/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.3103 - accuracy: 0.5000 - mse: 0.3103
# Epoch 27/512
# 4/4 [==============================] - 0s 526us/step - loss: 0.3086 - accuracy: 0.7500 - mse: 0.3086
# Epoch 28/512
# 4/4 [==============================] - 0s 485us/step - loss: 0.3042 - accuracy: 0.7500 - mse: 0.3042
# Epoch 29/512
# 4/4 [==============================] - 0s 495us/step - loss: 0.3050 - accuracy: 0.7500 - mse: 0.3050
# Epoch 30/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.3008 - accuracy: 0.7500 - mse: 0.3008
# Epoch 31/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.2988 - accuracy: 0.7500 - mse: 0.2988
# Epoch 32/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.2998 - accuracy: 0.7500 - mse: 0.2998
# Epoch 33/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.2981 - accuracy: 0.7500 - mse: 0.2981
# Epoch 34/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.2937 - accuracy: 0.7500 - mse: 0.2937
# Epoch 35/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.2920 - accuracy: 0.7500 - mse: 0.2920
# Epoch 36/512
# 4/4 [==============================] - 0s 630us/step - loss: 0.2931 - accuracy: 0.7500 - mse: 0.2931
# Epoch 37/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.2892 - accuracy: 0.7500 - mse: 0.2892
# Epoch 38/512
# 4/4 [==============================] - 0s 665us/step - loss: 0.2898 - accuracy: 0.7500 - mse: 0.2898
# Epoch 39/512
# 4/4 [==============================] - 0s 459us/step - loss: 0.2861 - accuracy: 0.7500 - mse: 0.2861
# Epoch 40/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.2843 - accuracy: 0.7500 - mse: 0.2843
# Epoch 41/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.2825 - accuracy: 0.7500 - mse: 0.2825
# Epoch 42/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.2812 - accuracy: 0.7500 - mse: 0.2812
# Epoch 43/512
# 4/4 [==============================] - 0s 499us/step - loss: 0.2799 - accuracy: 0.7500 - mse: 0.2799
# Epoch 44/512
# 4/4 [==============================] - 0s 714us/step - loss: 0.2782 - accuracy: 0.7500 - mse: 0.2782
# Epoch 45/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.2764 - accuracy: 0.7500 - mse: 0.2764
# Epoch 46/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.2748 - accuracy: 0.7500 - mse: 0.2748
# Epoch 47/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.2737 - accuracy: 0.7500 - mse: 0.2737
# Epoch 48/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.2724 - accuracy: 0.7500 - mse: 0.2724
# Epoch 49/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.2708 - accuracy: 0.7500 - mse: 0.2708
# Epoch 50/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.2695 - accuracy: 0.7500 - mse: 0.2695
# Epoch 51/512
# 4/4 [==============================] - 0s 424us/step - loss: 0.2676 - accuracy: 0.7500 - mse: 0.2676
# Epoch 52/512
# 4/4 [==============================] - 0s 443us/step - loss: 0.2666 - accuracy: 0.7500 - mse: 0.2666
# Epoch 53/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.2651 - accuracy: 0.7500 - mse: 0.2651
# Epoch 54/512
# 4/4 [==============================] - 0s 529us/step - loss: 0.2660 - accuracy: 0.7500 - mse: 0.2660
# Epoch 55/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.2645 - accuracy: 0.7500 - mse: 0.2645
# Epoch 56/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.2610 - accuracy: 0.7500 - mse: 0.2610
# Epoch 57/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.2596 - accuracy: 0.7500 - mse: 0.2596
# Epoch 58/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.2583 - accuracy: 0.7500 - mse: 0.2583
# Epoch 59/512
# 4/4 [==============================] - 0s 652us/step - loss: 0.2566 - accuracy: 0.7500 - mse: 0.2566
# Epoch 60/512
# 4/4 [==============================] - 0s 612us/step - loss: 0.2552 - accuracy: 0.7500 - mse: 0.2552
# Epoch 61/512
# 4/4 [==============================] - 0s 672us/step - loss: 0.2542 - accuracy: 0.7500 - mse: 0.2542
# Epoch 62/512
# 4/4 [==============================] - 0s 858us/step - loss: 0.2551 - accuracy: 0.7500 - mse: 0.2551
# Epoch 63/512
# 4/4 [==============================] - 0s 830us/step - loss: 0.2513 - accuracy: 0.7500 - mse: 0.2513
# Epoch 64/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.7500 - mse: 0.2500
# Epoch 65/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2487 - accuracy: 0.7500 - mse: 0.2487
# Epoch 66/512
# 4/4 [==============================] - 0s 922us/step - loss: 0.2499 - accuracy: 0.7500 - mse: 0.2499
# Epoch 67/512
# 4/4 [==============================] - 0s 870us/step - loss: 0.2464 - accuracy: 0.7500 - mse: 0.2464
# Epoch 68/512
# 4/4 [==============================] - 0s 891us/step - loss: 0.2448 - accuracy: 0.7500 - mse: 0.2448
# Epoch 69/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.2460 - accuracy: 0.7500 - mse: 0.2460
# Epoch 70/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.2427 - accuracy: 0.7500 - mse: 0.2427
# Epoch 71/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.2414 - accuracy: 0.7500 - mse: 0.2414
# Epoch 72/512
# 4/4 [==============================] - 0s 442us/step - loss: 0.2403 - accuracy: 0.7500 - mse: 0.2403
# Epoch 73/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.2387 - accuracy: 0.7500 - mse: 0.2387
# Epoch 74/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.2375 - accuracy: 0.7500 - mse: 0.2375
# Epoch 75/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.2363 - accuracy: 0.7500 - mse: 0.2363
# Epoch 76/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.2351 - accuracy: 0.7500 - mse: 0.2351
# Epoch 77/512
# 4/4 [==============================] - 0s 639us/step - loss: 0.2339 - accuracy: 0.7500 - mse: 0.2339
# Epoch 78/512
# 4/4 [==============================] - 0s 587us/step - loss: 0.2331 - accuracy: 0.7500 - mse: 0.2331
# Epoch 79/512
# 4/4 [==============================] - 0s 725us/step - loss: 0.2316 - accuracy: 0.7500 - mse: 0.2316
# Epoch 80/512
# 4/4 [==============================] - 0s 442us/step - loss: 0.2308 - accuracy: 0.7500 - mse: 0.2308
# Epoch 81/512
# 4/4 [==============================] - 0s 470us/step - loss: 0.2295 - accuracy: 0.7500 - mse: 0.2295
# Epoch 82/512
# 4/4 [==============================] - 0s 428us/step - loss: 0.2284 - accuracy: 0.7500 - mse: 0.2284
# Epoch 83/512
# 4/4 [==============================] - 0s 414us/step - loss: 0.2272 - accuracy: 0.7500 - mse: 0.2272
# Epoch 84/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.2281 - accuracy: 0.7500 - mse: 0.2281
# Epoch 85/512
# 4/4 [==============================] - 0s 555us/step - loss: 0.2247 - accuracy: 0.7500 - mse: 0.2247
# Epoch 86/512
# 4/4 [==============================] - 0s 565us/step - loss: 0.2239 - accuracy: 0.7500 - mse: 0.2239
# Epoch 87/512
# 4/4 [==============================] - 0s 694us/step - loss: 0.2246 - accuracy: 0.7500 - mse: 0.2246
# Epoch 88/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.2215 - accuracy: 0.7500 - mse: 0.2215
# Epoch 89/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.2203 - accuracy: 0.7500 - mse: 0.2203
# Epoch 90/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.2191 - accuracy: 0.7500 - mse: 0.2191
# Epoch 91/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.2181 - accuracy: 0.7500 - mse: 0.2181
# Epoch 92/512
# 4/4 [==============================] - 0s 421us/step - loss: 0.2191 - accuracy: 0.7500 - mse: 0.2191
# Epoch 93/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.2162 - accuracy: 0.7500 - mse: 0.2162
# Epoch 94/512
# 4/4 [==============================] - 0s 444us/step - loss: 0.2148 - accuracy: 0.7500 - mse: 0.2148
# Epoch 95/512
# 4/4 [==============================] - 0s 444us/step - loss: 0.2160 - accuracy: 0.7500 - mse: 0.2160
# Epoch 96/512
# 4/4 [==============================] - 0s 447us/step - loss: 0.2148 - accuracy: 0.7500 - mse: 0.2148
# Epoch 97/512
# 4/4 [==============================] - 0s 516us/step - loss: 0.2120 - accuracy: 0.7500 - mse: 0.2120
# Epoch 98/512
# 4/4 [==============================] - 0s 672us/step - loss: 0.2126 - accuracy: 0.7500 - mse: 0.2126
# Epoch 99/512
# 4/4 [==============================] - 0s 699us/step - loss: 0.2096 - accuracy: 0.7500 - mse: 0.2096
# Epoch 100/512
# 4/4 [==============================] - 0s 895us/step - loss: 0.2106 - accuracy: 0.7500 - mse: 0.2106
# Epoch 101/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.2079 - accuracy: 0.7500 - mse: 0.2079
# Epoch 102/512
# 4/4 [==============================] - 0s 442us/step - loss: 0.2069 - accuracy: 0.7500 - mse: 0.2069
# Epoch 103/512
# 4/4 [==============================] - 0s 447us/step - loss: 0.2076 - accuracy: 0.7500 - mse: 0.2076
# Epoch 104/512
# 4/4 [==============================] - 0s 552us/step - loss: 0.2046 - accuracy: 0.7500 - mse: 0.2046
# Epoch 105/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.2035 - accuracy: 0.7500 - mse: 0.2035
# Epoch 106/512
# 4/4 [==============================] - 0s 588us/step - loss: 0.2028 - accuracy: 0.7500 - mse: 0.2028
# Epoch 107/512
# 4/4 [==============================] - 0s 568us/step - loss: 0.2036 - accuracy: 0.7500 - mse: 0.2036
# Epoch 108/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.2025 - accuracy: 0.7500 - mse: 0.2025
# Epoch 109/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.2016 - accuracy: 0.7500 - mse: 0.2016
# Epoch 110/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.2005 - accuracy: 0.7500 - mse: 0.2005
# Epoch 111/512
# 4/4 [==============================] - 0s 578us/step - loss: 0.1976 - accuracy: 0.7500 - mse: 0.1976
# Epoch 112/512
# 4/4 [==============================] - 0s 787us/step - loss: 0.1986 - accuracy: 0.7500 - mse: 0.1986
# Epoch 113/512
# 4/4 [==============================] - 0s 596us/step - loss: 0.1957 - accuracy: 0.7500 - mse: 0.1957
# Epoch 114/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.1952 - accuracy: 0.7500 - mse: 0.1952
# Epoch 115/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.1941 - accuracy: 0.7500 - mse: 0.1941
# Epoch 116/512
# 4/4 [==============================] - 0s 716us/step - loss: 0.1930 - accuracy: 0.7500 - mse: 0.1930
# Epoch 117/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.1938 - accuracy: 0.7500 - mse: 0.1938
# Epoch 118/512
# 4/4 [==============================] - 0s 526us/step - loss: 0.1915 - accuracy: 0.7500 - mse: 0.1914
# Epoch 119/512
# 4/4 [==============================] - 0s 526us/step - loss: 0.1920 - accuracy: 0.7500 - mse: 0.1920
# Epoch 120/512
# 4/4 [==============================] - 0s 541us/step - loss: 0.1893 - accuracy: 0.7500 - mse: 0.1893
# Epoch 121/512
# 4/4 [==============================] - 0s 576us/step - loss: 0.1885 - accuracy: 0.7500 - mse: 0.1885
# Epoch 122/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.1893 - accuracy: 0.7500 - mse: 0.1893
# Epoch 123/512
# 4/4 [==============================] - 0s 580us/step - loss: 0.1883 - accuracy: 0.7500 - mse: 0.1883
# Epoch 124/512
# 4/4 [==============================] - 0s 636us/step - loss: 0.1860 - accuracy: 0.7500 - mse: 0.1860
# Epoch 125/512
# 4/4 [==============================] - 0s 488us/step - loss: 0.1865 - accuracy: 0.7500 - mse: 0.1865
# Epoch 126/512
# 4/4 [==============================] - 0s 549us/step - loss: 0.1857 - accuracy: 0.7500 - mse: 0.1857
# Epoch 127/512
# 4/4 [==============================] - 0s 546us/step - loss: 0.1832 - accuracy: 0.7500 - mse: 0.1832
# Epoch 128/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.1838 - accuracy: 0.7500 - mse: 0.1838
# Epoch 129/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.1812 - accuracy: 0.7500 - mse: 0.1812
# Epoch 130/512
# 4/4 [==============================] - 0s 461us/step - loss: 0.1806 - accuracy: 0.7500 - mse: 0.1806
# Epoch 131/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.1815 - accuracy: 0.7500 - mse: 0.1815
# Epoch 132/512
# 4/4 [==============================] - 0s 647us/step - loss: 0.1805 - accuracy: 0.7500 - mse: 0.1805
# Epoch 133/512
# 4/4 [==============================] - 0s 541us/step - loss: 0.1781 - accuracy: 0.7500 - mse: 0.1781
# Epoch 134/512
# 4/4 [==============================] - 0s 658us/step - loss: 0.1776 - accuracy: 0.7500 - mse: 0.1776
# Epoch 135/512
# 4/4 [==============================] - 0s 432us/step - loss: 0.1783 - accuracy: 0.7500 - mse: 0.1783
# Epoch 136/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.1758 - accuracy: 0.7500 - mse: 0.1758
# Epoch 137/512
# 4/4 [==============================] - 0s 447us/step - loss: 0.1768 - accuracy: 0.7500 - mse: 0.1768
# Epoch 138/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.1759 - accuracy: 0.7500 - mse: 0.1759
# Epoch 139/512
# 4/4 [==============================] - 0s 463us/step - loss: 0.1752 - accuracy: 0.7500 - mse: 0.1752
# Epoch 140/512
# 4/4 [==============================] - 0s 399us/step - loss: 0.1728 - accuracy: 0.7500 - mse: 0.1728
# Epoch 141/512
# 4/4 [==============================] - 0s 414us/step - loss: 0.1721 - accuracy: 0.7500 - mse: 0.1721
# Epoch 142/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.1718 - accuracy: 0.7500 - mse: 0.1718
# Epoch 143/512
# 4/4 [==============================] - 0s 447us/step - loss: 0.1710 - accuracy: 0.7500 - mse: 0.1710
# Epoch 144/512
# 4/4 [==============================] - 0s 410us/step - loss: 0.1700 - accuracy: 0.7500 - mse: 0.1700
# Epoch 145/512
# 4/4 [==============================] - 0s 431us/step - loss: 0.1708 - accuracy: 0.7500 - mse: 0.1708
# Epoch 146/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.1689 - accuracy: 0.7500 - mse: 0.1689
# Epoch 147/512
# 4/4 [==============================] - 0s 458us/step - loss: 0.1681 - accuracy: 0.7500 - mse: 0.1681
# Epoch 148/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.1675 - accuracy: 0.7500 - mse: 0.1675
# Epoch 149/512
# 4/4 [==============================] - 0s 484us/step - loss: 0.1679 - accuracy: 0.7500 - mse: 0.1679
# Epoch 150/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.1657 - accuracy: 0.7500 - mse: 0.1657
# Epoch 151/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.1653 - accuracy: 0.7500 - mse: 0.1653
# Epoch 152/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.1647 - accuracy: 0.7500 - mse: 0.1647
# Epoch 153/512
# 4/4 [==============================] - 0s 575us/step - loss: 0.1651 - accuracy: 0.7500 - mse: 0.1651
# Epoch 154/512
# 4/4 [==============================] - 0s 667us/step - loss: 0.1630 - accuracy: 0.7500 - mse: 0.1630
# Epoch 155/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.1625 - accuracy: 0.7500 - mse: 0.1625
# Epoch 156/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.1631 - accuracy: 0.7500 - mse: 0.1631
# Epoch 157/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.1609 - accuracy: 0.7500 - mse: 0.1609
# Epoch 158/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.1602 - accuracy: 0.7500 - mse: 0.1602
# Epoch 159/512
# 4/4 [==============================] - 0s 677us/step - loss: 0.1612 - accuracy: 0.7500 - mse: 0.1612
# Epoch 160/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.1604 - accuracy: 0.7500 - mse: 0.1604
# Epoch 161/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.1597 - accuracy: 0.7500 - mse: 0.1597
# Epoch 162/512
# 4/4 [==============================] - 0s 541us/step - loss: 0.1590 - accuracy: 0.7500 - mse: 0.1590
# Epoch 163/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.1585 - accuracy: 0.7500 - mse: 0.1585
# Epoch 164/512
# 4/4 [==============================] - 0s 587us/step - loss: 0.1565 - accuracy: 0.7500 - mse: 0.1565
# Epoch 165/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.1571 - accuracy: 0.7500 - mse: 0.1571
# Epoch 166/512
# 4/4 [==============================] - 0s 558us/step - loss: 0.1563 - accuracy: 0.7500 - mse: 0.1563
# Epoch 167/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.1560 - accuracy: 0.7500 - mse: 0.1560
# Epoch 168/512
# 4/4 [==============================] - 0s 571us/step - loss: 0.1551 - accuracy: 0.7500 - mse: 0.1551
# Epoch 169/512
# 4/4 [==============================] - 0s 540us/step - loss: 0.1534 - accuracy: 0.7500 - mse: 0.1534
# Epoch 170/512
# 4/4 [==============================] - 0s 700us/step - loss: 0.1538 - accuracy: 0.7500 - mse: 0.1538
# Epoch 171/512
# 4/4 [==============================] - 0s 575us/step - loss: 0.1531 - accuracy: 0.7500 - mse: 0.1531
# Epoch 172/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.1512 - accuracy: 0.7500 - mse: 0.1512
# Epoch 173/512
# 4/4 [==============================] - 0s 491us/step - loss: 0.1520 - accuracy: 0.7500 - mse: 0.1520
# Epoch 174/512
# 4/4 [==============================] - 0s 493us/step - loss: 0.1503 - accuracy: 0.7500 - mse: 0.1503
# Epoch 175/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.1496 - accuracy: 0.7500 - mse: 0.1496
# Epoch 176/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.1491 - accuracy: 0.7500 - mse: 0.1491
# Epoch 177/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.1483 - accuracy: 0.7500 - mse: 0.1483
# Epoch 178/512
# 4/4 [==============================] - 0s 547us/step - loss: 0.1479 - accuracy: 0.7500 - mse: 0.1479
# Epoch 179/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.1471 - accuracy: 0.7500 - mse: 0.1471
# Epoch 180/512
# 4/4 [==============================] - 0s 504us/step - loss: 0.1477 - accuracy: 0.7500 - mse: 0.1477
# Epoch 181/512
# 4/4 [==============================] - 0s 522us/step - loss: 0.1470 - accuracy: 0.7500 - mse: 0.1470
# Epoch 182/512
# 4/4 [==============================] - 0s 537us/step - loss: 0.1454 - accuracy: 0.7500 - mse: 0.1454
# Epoch 183/512
# 4/4 [==============================] - 0s 602us/step - loss: 0.1447 - accuracy: 0.7500 - mse: 0.1447
# Epoch 184/512
# 4/4 [==============================] - 0s 720us/step - loss: 0.1455 - accuracy: 0.7500 - mse: 0.1455
# Epoch 185/512
# 4/4 [==============================] - 0s 551us/step - loss: 0.1436 - accuracy: 0.7500 - mse: 0.1436
# Epoch 186/512
# 4/4 [==============================] - 0s 887us/step - loss: 0.1441 - accuracy: 0.7500 - mse: 0.1441
# Epoch 187/512
# 4/4 [==============================] - 0s 491us/step - loss: 0.1424 - accuracy: 0.7500 - mse: 0.1424
# Epoch 188/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.1428 - accuracy: 0.7500 - mse: 0.1428
# Epoch 189/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.1410 - accuracy: 0.7500 - mse: 0.1410
# Epoch 190/512
# 4/4 [==============================] - 0s 591us/step - loss: 0.1404 - accuracy: 0.7500 - mse: 0.1404
# Epoch 191/512
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1413 - accuracy: 0.7500 - mse: 0.1413
# Epoch 192/512
# 4/4 [==============================] - 0s 539us/step - loss: 0.1395 - accuracy: 0.7500 - mse: 0.1395
# Epoch 193/512
# 4/4 [==============================] - 0s 419us/step - loss: 0.1387 - accuracy: 0.7500 - mse: 0.1387
# Epoch 194/512
# 4/4 [==============================] - 0s 449us/step - loss: 0.1394 - accuracy: 0.7500 - mse: 0.1394
# Epoch 195/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.1376 - accuracy: 0.7500 - mse: 0.1376
# Epoch 196/512
# 4/4 [==============================] - 0s 640us/step - loss: 0.1372 - accuracy: 0.7500 - mse: 0.1372
# Epoch 197/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.1364 - accuracy: 0.7500 - mse: 0.1364
# Epoch 198/512
# 4/4 [==============================] - 0s 657us/step - loss: 0.1361 - accuracy: 0.7500 - mse: 0.1361
# Epoch 199/512
# 4/4 [==============================] - 0s 697us/step - loss: 0.1368 - accuracy: 0.7500 - mse: 0.1368
# Epoch 200/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.1350 - accuracy: 0.7500 - mse: 0.1350
# Epoch 201/512
# 4/4 [==============================] - 0s 447us/step - loss: 0.1355 - accuracy: 0.7500 - mse: 0.1355
# Epoch 202/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.1337 - accuracy: 0.7500 - mse: 0.1337
# Epoch 203/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.1343 - accuracy: 0.7500 - mse: 0.1343
# Epoch 204/512
# 4/4 [==============================] - 0s 488us/step - loss: 0.1329 - accuracy: 0.7500 - mse: 0.1329
# Epoch 205/512
# 4/4 [==============================] - 0s 563us/step - loss: 0.1334 - accuracy: 0.7500 - mse: 0.1334
# Epoch 206/512
# 4/4 [==============================] - 0s 632us/step - loss: 0.1328 - accuracy: 0.7500 - mse: 0.1328
# Epoch 207/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.1322 - accuracy: 0.7500 - mse: 0.1322
# Epoch 208/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.1307 - accuracy: 0.7500 - mse: 0.1307
# Epoch 209/512
# 4/4 [==============================] - 0s 444us/step - loss: 0.1311 - accuracy: 0.7500 - mse: 0.1311
# Epoch 210/512
# 4/4 [==============================] - 0s 626us/step - loss: 0.1295 - accuracy: 0.7500 - mse: 0.1295
# Epoch 211/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.1289 - accuracy: 0.7500 - mse: 0.1289
# Epoch 212/512
# 4/4 [==============================] - 0s 477us/step - loss: 0.1295 - accuracy: 0.7500 - mse: 0.1295
# Epoch 213/512
# 4/4 [==============================] - 0s 424us/step - loss: 0.1279 - accuracy: 0.7500 - mse: 0.1279
# Epoch 214/512
# 4/4 [==============================] - 0s 426us/step - loss: 0.1273 - accuracy: 0.7500 - mse: 0.1273
# Epoch 215/512
# 4/4 [==============================] - 0s 563us/step - loss: 0.1280 - accuracy: 0.7500 - mse: 0.1280
# Epoch 216/512
# 4/4 [==============================] - 0s 533us/step - loss: 0.1273 - accuracy: 0.7500 - mse: 0.1273
# Epoch 217/512
# 4/4 [==============================] - 0s 536us/step - loss: 0.1258 - accuracy: 0.7500 - mse: 0.1258
# Epoch 218/512
# 4/4 [==============================] - 0s 604us/step - loss: 0.1265 - accuracy: 0.7500 - mse: 0.1265
# Epoch 219/512
# 4/4 [==============================] - 0s 771us/step - loss: 0.1250 - accuracy: 0.7500 - mse: 0.1250
# Epoch 220/512
# 4/4 [==============================] - 0s 525us/step - loss: 0.1242 - accuracy: 0.7500 - mse: 0.1242
# Epoch 221/512
# 4/4 [==============================] - 0s 539us/step - loss: 0.1249 - accuracy: 0.7500 - mse: 0.1249
# Epoch 222/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.1243 - accuracy: 0.7500 - mse: 0.1243
# Epoch 223/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.1230 - accuracy: 0.7500 - mse: 0.1230
# Epoch 224/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.1224 - accuracy: 0.7500 - mse: 0.1224
# Epoch 225/512
# 4/4 [==============================] - 0s 462us/step - loss: 0.1217 - accuracy: 0.7500 - mse: 0.1217
# Epoch 226/512
# 4/4 [==============================] - 0s 586us/step - loss: 0.1213 - accuracy: 0.7500 - mse: 0.1213
# Epoch 227/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.1218 - accuracy: 0.7500 - mse: 0.1218
# Epoch 228/512
# 4/4 [==============================] - 0s 509us/step - loss: 0.1214 - accuracy: 0.7500 - mse: 0.1214
# Epoch 229/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.1197 - accuracy: 0.7500 - mse: 0.1197
# Epoch 230/512
# 4/4 [==============================] - 0s 513us/step - loss: 0.1196 - accuracy: 0.7500 - mse: 0.1196
# Epoch 231/512
# 4/4 [==============================] - 0s 442us/step - loss: 0.1190 - accuracy: 0.7500 - mse: 0.1190
# Epoch 232/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.1195 - accuracy: 0.7500 - mse: 0.1195
# Epoch 233/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.1180 - accuracy: 0.7500 - mse: 0.1180
# Epoch 234/512
# 4/4 [==============================] - 0s 437us/step - loss: 0.1174 - accuracy: 0.7500 - mse: 0.1174
# Epoch 235/512
# 4/4 [==============================] - 0s 444us/step - loss: 0.1178 - accuracy: 0.7500 - mse: 0.1178
# Epoch 236/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.1174 - accuracy: 0.7500 - mse: 0.1174
# Epoch 237/512
# 4/4 [==============================] - 0s 490us/step - loss: 0.1161 - accuracy: 0.7500 - mse: 0.1161
# Epoch 238/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.1155 - accuracy: 0.7500 - mse: 0.1155
# Epoch 239/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.1153 - accuracy: 0.7500 - mse: 0.1153
# Epoch 240/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.1145 - accuracy: 0.7500 - mse: 0.1145
# Epoch 241/512
# 4/4 [==============================] - 0s 813us/step - loss: 0.1143 - accuracy: 0.7500 - mse: 0.1143
# Epoch 242/512
# 4/4 [==============================] - 0s 884us/step - loss: 0.1138 - accuracy: 0.7500 - mse: 0.1138
# Epoch 243/512
# 4/4 [==============================] - 0s 947us/step - loss: 0.1133 - accuracy: 0.7500 - mse: 0.1133
# Epoch 244/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.1127 - accuracy: 0.7500 - mse: 0.1127
# Epoch 245/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.1122 - accuracy: 0.7500 - mse: 0.1122
# Epoch 246/512
# 4/4 [==============================] - 0s 520us/step - loss: 0.1117 - accuracy: 0.7500 - mse: 0.1117
# Epoch 247/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.1115 - accuracy: 0.7500 - mse: 0.1115
# Epoch 248/512
# 4/4 [==============================] - 0s 492us/step - loss: 0.1110 - accuracy: 0.7500 - mse: 0.1110
# Epoch 249/512
# 4/4 [==============================] - 0s 557us/step - loss: 0.1105 - accuracy: 0.7500 - mse: 0.1105
# Epoch 250/512
# 4/4 [==============================] - 0s 694us/step - loss: 0.1101 - accuracy: 0.7500 - mse: 0.1101
# Epoch 251/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.1105 - accuracy: 0.7500 - mse: 0.1105
# Epoch 252/512
# 4/4 [==============================] - 0s 431us/step - loss: 0.1100 - accuracy: 0.7500 - mse: 0.1100
# Epoch 253/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.1086 - accuracy: 0.7500 - mse: 0.1086
# Epoch 254/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.1083 - accuracy: 0.7500 - mse: 0.1083
# Epoch 255/512
# 4/4 [==============================] - 0s 460us/step - loss: 0.1079 - accuracy: 0.7500 - mse: 0.1079
# Epoch 256/512
# 4/4 [==============================] - 0s 431us/step - loss: 0.1084 - accuracy: 0.7500 - mse: 0.1084
# Epoch 257/512
# 4/4 [==============================] - 0s 556us/step - loss: 0.1071 - accuracy: 0.7500 - mse: 0.1071
# Epoch 258/512
# 4/4 [==============================] - 0s 426us/step - loss: 0.1066 - accuracy: 0.7500 - mse: 0.1066
# Epoch 259/512
# 4/4 [==============================] - 0s 414us/step - loss: 0.1061 - accuracy: 0.7500 - mse: 0.1061
# Epoch 260/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.1067 - accuracy: 0.7500 - mse: 0.1067
# Epoch 261/512
# 4/4 [==============================] - 0s 426us/step - loss: 0.1062 - accuracy: 0.7500 - mse: 0.1062
# Epoch 262/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.1050 - accuracy: 0.7500 - mse: 0.1050
# Epoch 263/512
# 4/4 [==============================] - 0s 415us/step - loss: 0.1046 - accuracy: 0.7500 - mse: 0.1046
# Epoch 264/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.1041 - accuracy: 0.7500 - mse: 0.1041
# Epoch 265/512
# 4/4 [==============================] - 0s 485us/step - loss: 0.1036 - accuracy: 0.7500 - mse: 0.1036
# Epoch 266/512
# 4/4 [==============================] - 0s 443us/step - loss: 0.1033 - accuracy: 0.7500 - mse: 0.1033
# Epoch 267/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.1037 - accuracy: 0.7500 - mse: 0.1037
# Epoch 268/512
# 4/4 [==============================] - 0s 484us/step - loss: 0.1034 - accuracy: 0.7500 - mse: 0.1034
# Epoch 269/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.1020 - accuracy: 0.7500 - mse: 0.1020
# Epoch 270/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.1025 - accuracy: 0.7500 - mse: 0.1025
# Epoch 271/512
# 4/4 [==============================] - 0s 774us/step - loss: 0.1013 - accuracy: 0.7500 - mse: 0.1013
# Epoch 272/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.1008 - accuracy: 0.7500 - mse: 0.1008
# Epoch 273/512
# 4/4 [==============================] - 0s 751us/step - loss: 0.1006 - accuracy: 0.7500 - mse: 0.1006
# Epoch 274/512
# 4/4 [==============================] - 0s 437us/step - loss: 0.1011 - accuracy: 0.7500 - mse: 0.1011
# Epoch 275/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.0998 - accuracy: 0.7500 - mse: 0.0998
# Epoch 276/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.1002 - accuracy: 0.7500 - mse: 0.1002
# Epoch 277/512
# 4/4 [==============================] - 0s 475us/step - loss: 0.0989 - accuracy: 0.7500 - mse: 0.0989
# Epoch 278/512
# 4/4 [==============================] - 0s 439us/step - loss: 0.0993 - accuracy: 0.7500 - mse: 0.0993
# Epoch 279/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0991 - accuracy: 0.7500 - mse: 0.0991
# Epoch 280/512
# 4/4 [==============================] - 0s 528us/step - loss: 0.0980 - accuracy: 0.7500 - mse: 0.0980
# Epoch 281/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.0974 - accuracy: 0.7500 - mse: 0.0974
# Epoch 282/512
# 4/4 [==============================] - 0s 600us/step - loss: 0.0971 - accuracy: 0.7500 - mse: 0.0971
# Epoch 283/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.0974 - accuracy: 0.7500 - mse: 0.0974
# Epoch 284/512
# 4/4 [==============================] - 0s 608us/step - loss: 0.0962 - accuracy: 0.7500 - mse: 0.0962
# Epoch 285/512
# 4/4 [==============================] - 0s 578us/step - loss: 0.0959 - accuracy: 0.7500 - mse: 0.0959
# Epoch 286/512
# 4/4 [==============================] - 0s 445us/step - loss: 0.0957 - accuracy: 0.7500 - mse: 0.0957
# Epoch 287/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.0952 - accuracy: 0.7500 - mse: 0.0952
# Epoch 288/512
# 4/4 [==============================] - 0s 491us/step - loss: 0.0948 - accuracy: 0.7500 - mse: 0.0948
# Epoch 289/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.0944 - accuracy: 0.7500 - mse: 0.0944
# Epoch 290/512
# 4/4 [==============================] - 0s 434us/step - loss: 0.0941 - accuracy: 0.7500 - mse: 0.0941
# Epoch 291/512
# 4/4 [==============================] - 0s 624us/step - loss: 0.0938 - accuracy: 0.7500 - mse: 0.0938
# Epoch 292/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.0935 - accuracy: 0.7500 - mse: 0.0935
# Epoch 293/512
# 4/4 [==============================] - 0s 527us/step - loss: 0.0930 - accuracy: 0.7500 - mse: 0.0930
# Epoch 294/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.0927 - accuracy: 0.7500 - mse: 0.0927
# Epoch 295/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0923 - accuracy: 0.7500 - mse: 0.0923
# Epoch 296/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.0926 - accuracy: 0.7500 - mse: 0.0926
# Epoch 297/512
# 4/4 [==============================] - 0s 583us/step - loss: 0.0926 - accuracy: 0.7500 - mse: 0.0926
# Epoch 298/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.0912 - accuracy: 0.7500 - mse: 0.0912
# Epoch 299/512
# 4/4 [==============================] - 0s 618us/step - loss: 0.0908 - accuracy: 0.7500 - mse: 0.0908
# Epoch 300/512
# 4/4 [==============================] - 0s 432us/step - loss: 0.0905 - accuracy: 0.7500 - mse: 0.0905
# Epoch 301/512
# 4/4 [==============================] - 0s 510us/step - loss: 0.0903 - accuracy: 0.7500 - mse: 0.0903
# Epoch 302/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0907 - accuracy: 0.7500 - mse: 0.0907
# Epoch 303/512
# 4/4 [==============================] - 0s 437us/step - loss: 0.0896 - accuracy: 0.7500 - mse: 0.0896
# Epoch 304/512
# 4/4 [==============================] - 0s 562us/step - loss: 0.0898 - accuracy: 0.7500 - mse: 0.0898
# Epoch 305/512
# 4/4 [==============================] - 0s 573us/step - loss: 0.0887 - accuracy: 0.7500 - mse: 0.0887
# Epoch 306/512
# 4/4 [==============================] - 0s 545us/step - loss: 0.0884 - accuracy: 0.7500 - mse: 0.0884
# Epoch 307/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.0881 - accuracy: 0.7500 - mse: 0.0881
# Epoch 308/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0884 - accuracy: 0.7500 - mse: 0.0884
# Epoch 309/512
# 4/4 [==============================] - 0s 864us/step - loss: 0.0873 - accuracy: 0.7500 - mse: 0.0873
# Epoch 310/512
# 4/4 [==============================] - 0s 525us/step - loss: 0.0871 - accuracy: 0.7500 - mse: 0.0871
# Epoch 311/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.0874 - accuracy: 0.7500 - mse: 0.0874
# Epoch 312/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.0864 - accuracy: 1.0000 - mse: 0.0864
# Epoch 313/512
# 4/4 [==============================] - 0s 708us/step - loss: 0.0860 - accuracy: 1.0000 - mse: 0.0860
# Epoch 314/512
# 4/4 [==============================] - 0s 780us/step - loss: 0.0858 - accuracy: 1.0000 - mse: 0.0858
# Epoch 315/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.0854 - accuracy: 1.0000 - mse: 0.0854
# Epoch 316/512
# 4/4 [==============================] - 0s 465us/step - loss: 0.0858 - accuracy: 1.0000 - mse: 0.0858
# Epoch 317/512
# 4/4 [==============================] - 0s 551us/step - loss: 0.0848 - accuracy: 1.0000 - mse: 0.0848
# Epoch 318/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.0845 - accuracy: 1.0000 - mse: 0.0845
# Epoch 319/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.0840 - accuracy: 1.0000 - mse: 0.0840
# Epoch 320/512
# 4/4 [==============================] - 0s 547us/step - loss: 0.0845 - accuracy: 1.0000 - mse: 0.0845
# Epoch 321/512
# 4/4 [==============================] - 0s 689us/step - loss: 0.0834 - accuracy: 1.0000 - mse: 0.0834
# Epoch 322/512
# 4/4 [==============================] - 0s 692us/step - loss: 0.0837 - accuracy: 1.0000 - mse: 0.0837
# Epoch 323/512
# 4/4 [==============================] - 0s 619us/step - loss: 0.0828 - accuracy: 1.0000 - mse: 0.0828
# Epoch 324/512
# 4/4 [==============================] - 0s 434us/step - loss: 0.0830 - accuracy: 1.0000 - mse: 0.0830
# Epoch 325/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.0822 - accuracy: 1.0000 - mse: 0.0822
# Epoch 326/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.0819 - accuracy: 1.0000 - mse: 0.0819
# Epoch 327/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.0816 - accuracy: 1.0000 - mse: 0.0816
# Epoch 328/512
# 4/4 [==============================] - 0s 595us/step - loss: 0.0811 - accuracy: 1.0000 - mse: 0.0811
# Epoch 329/512
# 4/4 [==============================] - 0s 500us/step - loss: 0.0816 - accuracy: 1.0000 - mse: 0.0816
# Epoch 330/512
# 4/4 [==============================] - 0s 867us/step - loss: 0.0813 - accuracy: 1.0000 - mse: 0.0813
# Epoch 331/512
# 4/4 [==============================] - 0s 505us/step - loss: 0.0809 - accuracy: 1.0000 - mse: 0.0809
# Epoch 332/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.0800 - accuracy: 1.0000 - mse: 0.0800
# Epoch 333/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.0797 - accuracy: 1.0000 - mse: 0.0797
# Epoch 334/512
# 4/4 [==============================] - 0s 497us/step - loss: 0.0794 - accuracy: 1.0000 - mse: 0.0794
# Epoch 335/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.0790 - accuracy: 1.0000 - mse: 0.0790
# Epoch 336/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0795 - accuracy: 1.0000 - mse: 0.0795
# Epoch 337/512
# 4/4 [==============================] - 0s 531us/step - loss: 0.0790 - accuracy: 1.0000 - mse: 0.0790
# Epoch 338/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.0781 - accuracy: 1.0000 - mse: 0.0781
# Epoch 339/512
# 4/4 [==============================] - 0s 694us/step - loss: 0.0783 - accuracy: 1.0000 - mse: 0.0783
# Epoch 340/512
# 4/4 [==============================] - 0s 723us/step - loss: 0.0775 - accuracy: 1.0000 - mse: 0.0775
# Epoch 341/512
# 4/4 [==============================] - 0s 533us/step - loss: 0.0780 - accuracy: 1.0000 - mse: 0.0780
# Epoch 342/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0775 - accuracy: 1.0000 - mse: 0.0775
# Epoch 343/512
# 4/4 [==============================] - 0s 484us/step - loss: 0.0765 - accuracy: 1.0000 - mse: 0.0765
# Epoch 344/512
# 4/4 [==============================] - 0s 749us/step - loss: 0.0763 - accuracy: 1.0000 - mse: 0.0763
# Epoch 345/512
# 4/4 [==============================] - 0s 502us/step - loss: 0.0760 - accuracy: 1.0000 - mse: 0.0760
# Epoch 346/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.0757 - accuracy: 1.0000 - mse: 0.0757
# Epoch 347/512
# 4/4 [==============================] - 0s 463us/step - loss: 0.0761 - accuracy: 1.0000 - mse: 0.0761
# Epoch 348/512
# 4/4 [==============================] - 0s 529us/step - loss: 0.0752 - accuracy: 1.0000 - mse: 0.0752
# Epoch 349/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.0748 - accuracy: 1.0000 - mse: 0.0748
# Epoch 350/512
# 4/4 [==============================] - 0s 506us/step - loss: 0.0745 - accuracy: 1.0000 - mse: 0.0745
# Epoch 351/512
# 4/4 [==============================] - 0s 459us/step - loss: 0.0741 - accuracy: 1.0000 - mse: 0.0741
# Epoch 352/512
# 4/4 [==============================] - 0s 436us/step - loss: 0.0740 - accuracy: 1.0000 - mse: 0.0740
# Epoch 353/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0737 - accuracy: 1.0000 - mse: 0.0737
# Epoch 354/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.0734 - accuracy: 1.0000 - mse: 0.0734
# Epoch 355/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.0737 - accuracy: 1.0000 - mse: 0.0737
# Epoch 356/512
# 4/4 [==============================] - 0s 493us/step - loss: 0.0729 - accuracy: 1.0000 - mse: 0.0729
# Epoch 357/512
# 4/4 [==============================] - 0s 604us/step - loss: 0.0725 - accuracy: 1.0000 - mse: 0.0725
# Epoch 358/512
# 4/4 [==============================] - 0s 595us/step - loss: 0.0728 - accuracy: 1.0000 - mse: 0.0728
# Epoch 359/512
# 4/4 [==============================] - 0s 516us/step - loss: 0.0720 - accuracy: 1.0000 - mse: 0.0720
# Epoch 360/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.0717 - accuracy: 1.0000 - mse: 0.0717
# Epoch 361/512
# 4/4 [==============================] - 0s 895us/step - loss: 0.0713 - accuracy: 1.0000 - mse: 0.0713
# Epoch 362/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.0716 - accuracy: 1.0000 - mse: 0.0716
# Epoch 363/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.0708 - accuracy: 1.0000 - mse: 0.0708
# Epoch 364/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.0705 - accuracy: 1.0000 - mse: 0.0705
# Epoch 365/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.0703 - accuracy: 1.0000 - mse: 0.0703
# Epoch 366/512
# 4/4 [==============================] - 0s 517us/step - loss: 0.0700 - accuracy: 1.0000 - mse: 0.0700
# Epoch 367/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.0697 - accuracy: 1.0000 - mse: 0.0697
# Epoch 368/512
# 4/4 [==============================] - 0s 652us/step - loss: 0.0696 - accuracy: 1.0000 - mse: 0.0696
# Epoch 369/512
# 4/4 [==============================] - 0s 431us/step - loss: 0.0697 - accuracy: 1.0000 - mse: 0.0697
# Epoch 370/512
# 4/4 [==============================] - 0s 422us/step - loss: 0.0690 - accuracy: 1.0000 - mse: 0.0690
# Epoch 371/512
# 4/4 [==============================] - 0s 417us/step - loss: 0.0687 - accuracy: 1.0000 - mse: 0.0687
# Epoch 372/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.0683 - accuracy: 1.0000 - mse: 0.0683
# Epoch 373/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.0681 - accuracy: 1.0000 - mse: 0.0681
# Epoch 374/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.0685 - accuracy: 1.0000 - mse: 0.0685
# Epoch 375/512
# 4/4 [==============================] - 0s 478us/step - loss: 0.0675 - accuracy: 1.0000 - mse: 0.0675
# Epoch 376/512
# 4/4 [==============================] - 0s 443us/step - loss: 0.0673 - accuracy: 1.0000 - mse: 0.0673
# Epoch 377/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.0670 - accuracy: 1.0000 - mse: 0.0670
# Epoch 378/512
# 4/4 [==============================] - 0s 409us/step - loss: 0.0668 - accuracy: 1.0000 - mse: 0.0668
# Epoch 379/512
# 4/4 [==============================] - 0s 453us/step - loss: 0.0671 - accuracy: 1.0000 - mse: 0.0671
# Epoch 380/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.0663 - accuracy: 1.0000 - mse: 0.0663
# Epoch 381/512
# 4/4 [==============================] - 0s 659us/step - loss: 0.0660 - accuracy: 1.0000 - mse: 0.0660
# Epoch 382/512
# 4/4 [==============================] - 0s 702us/step - loss: 0.0663 - accuracy: 1.0000 - mse: 0.0663
# Epoch 383/512
# 4/4 [==============================] - 0s 525us/step - loss: 0.0655 - accuracy: 1.0000 - mse: 0.0655
# Epoch 384/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.0658 - accuracy: 1.0000 - mse: 0.0658
# Epoch 385/512
# 4/4 [==============================] - 0s 542us/step - loss: 0.0650 - accuracy: 1.0000 - mse: 0.0650
# Epoch 386/512
# 4/4 [==============================] - 0s 627us/step - loss: 0.0648 - accuracy: 1.0000 - mse: 0.0648
# Epoch 387/512
# 4/4 [==============================] - 0s 457us/step - loss: 0.0649 - accuracy: 1.0000 - mse: 0.0649
# Epoch 388/512
# 4/4 [==============================] - 0s 447us/step - loss: 0.0642 - accuracy: 1.0000 - mse: 0.0642
# Epoch 389/512
# 4/4 [==============================] - 0s 507us/step - loss: 0.0639 - accuracy: 1.0000 - mse: 0.0639
# Epoch 390/512
# 4/4 [==============================] - 0s 606us/step - loss: 0.0637 - accuracy: 1.0000 - mse: 0.0637
# Epoch 391/512
# 4/4 [==============================] - 0s 583us/step - loss: 0.0635 - accuracy: 1.0000 - mse: 0.0635
# Epoch 392/512
# 4/4 [==============================] - 0s 810us/step - loss: 0.0637 - accuracy: 1.0000 - mse: 0.0637
# Epoch 393/512
# 4/4 [==============================] - 0s 489us/step - loss: 0.0629 - accuracy: 1.0000 - mse: 0.0629
# Epoch 394/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.0626 - accuracy: 1.0000 - mse: 0.0626
# Epoch 395/512
# 4/4 [==============================] - 0s 440us/step - loss: 0.0624 - accuracy: 1.0000 - mse: 0.0624
# Epoch 396/512
# 4/4 [==============================] - 0s 411us/step - loss: 0.0622 - accuracy: 1.0000 - mse: 0.0622
# Epoch 397/512
# 4/4 [==============================] - 0s 441us/step - loss: 0.0619 - accuracy: 1.0000 - mse: 0.0619
# Epoch 398/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0623 - accuracy: 1.0000 - mse: 0.0623
# Epoch 399/512
# 4/4 [==============================] - 0s 455us/step - loss: 0.0615 - accuracy: 1.0000 - mse: 0.0615
# Epoch 400/512
# 4/4 [==============================] - 0s 418us/step - loss: 0.0612 - accuracy: 1.0000 - mse: 0.0612
# Epoch 401/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0610 - accuracy: 1.0000 - mse: 0.0610
# Epoch 402/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0607 - accuracy: 1.0000 - mse: 0.0607
# Epoch 403/512
# 4/4 [==============================] - 0s 466us/step - loss: 0.0609 - accuracy: 1.0000 - mse: 0.0609
# Epoch 404/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.0603 - accuracy: 1.0000 - mse: 0.0603
# Epoch 405/512
# 4/4 [==============================] - 0s 543us/step - loss: 0.0600 - accuracy: 1.0000 - mse: 0.0600
# Epoch 406/512
# 4/4 [==============================] - 0s 534us/step - loss: 0.0598 - accuracy: 1.0000 - mse: 0.0598
# Epoch 407/512
# 4/4 [==============================] - 0s 787us/step - loss: 0.0596 - accuracy: 1.0000 - mse: 0.0596
# Epoch 408/512
# 4/4 [==============================] - 0s 620us/step - loss: 0.0593 - accuracy: 1.0000 - mse: 0.0593
# Epoch 409/512
# 4/4 [==============================] - 0s 766us/step - loss: 0.0592 - accuracy: 1.0000 - mse: 0.0592
# Epoch 410/512
# 4/4 [==============================] - 0s 514us/step - loss: 0.0593 - accuracy: 1.0000 - mse: 0.0593
# Epoch 411/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.0586 - accuracy: 1.0000 - mse: 0.0586
# Epoch 412/512
# 4/4 [==============================] - 0s 432us/step - loss: 0.0584 - accuracy: 1.0000 - mse: 0.0584
# Epoch 413/512
# 4/4 [==============================] - 0s 513us/step - loss: 0.0587 - accuracy: 1.0000 - mse: 0.0587
# Epoch 414/512
# 4/4 [==============================] - 0s 548us/step - loss: 0.0583 - accuracy: 1.0000 - mse: 0.0583
# Epoch 415/512
# 4/4 [==============================] - 0s 544us/step - loss: 0.0577 - accuracy: 1.0000 - mse: 0.0577
# Epoch 416/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.0574 - accuracy: 1.0000 - mse: 0.0574
# Epoch 417/512
# 4/4 [==============================] - 0s 532us/step - loss: 0.0574 - accuracy: 1.0000 - mse: 0.0574
# Epoch 418/512
# 4/4 [==============================] - 0s 634us/step - loss: 0.0570 - accuracy: 1.0000 - mse: 0.0570
# Epoch 419/512
# 4/4 [==============================] - 0s 594us/step - loss: 0.0567 - accuracy: 1.0000 - mse: 0.0567
# Epoch 420/512
# 4/4 [==============================] - 0s 634us/step - loss: 0.0565 - accuracy: 1.0000 - mse: 0.0565
# Epoch 421/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.0563 - accuracy: 1.0000 - mse: 0.0563
# Epoch 422/512
# 4/4 [==============================] - 0s 603us/step - loss: 0.0562 - accuracy: 1.0000 - mse: 0.0562
# Epoch 423/512
# 4/4 [==============================] - 0s 430us/step - loss: 0.0560 - accuracy: 1.0000 - mse: 0.0560
# Epoch 424/512
# 4/4 [==============================] - 0s 515us/step - loss: 0.0558 - accuracy: 1.0000 - mse: 0.0558
# Epoch 425/512
# 4/4 [==============================] - 0s 401us/step - loss: 0.0555 - accuracy: 1.0000 - mse: 0.0555
# Epoch 426/512
# 4/4 [==============================] - 0s 480us/step - loss: 0.0552 - accuracy: 1.0000 - mse: 0.0552
# Epoch 427/512
# 4/4 [==============================] - 0s 501us/step - loss: 0.0556 - accuracy: 1.0000 - mse: 0.0556
# Epoch 428/512
# 4/4 [==============================] - 0s 539us/step - loss: 0.0553 - accuracy: 1.0000 - mse: 0.0553
# Epoch 429/512
# 4/4 [==============================] - 0s 516us/step - loss: 0.0547 - accuracy: 1.0000 - mse: 0.0547
# Epoch 430/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0544 - accuracy: 1.0000 - mse: 0.0544
# Epoch 431/512
# 4/4 [==============================] - 0s 430us/step - loss: 0.0547 - accuracy: 1.0000 - mse: 0.0547
# Epoch 432/512
# 4/4 [==============================] - 0s 633us/step - loss: 0.0541 - accuracy: 1.0000 - mse: 0.0541
# Epoch 433/512
# 4/4 [==============================] - 0s 768us/step - loss: 0.0539 - accuracy: 1.0000 - mse: 0.0539
# Epoch 434/512
# 4/4 [==============================] - 0s 703us/step - loss: 0.0536 - accuracy: 1.0000 - mse: 0.0536
# Epoch 435/512
# 4/4 [==============================] - 0s 442us/step - loss: 0.0534 - accuracy: 1.0000 - mse: 0.0534
# Epoch 436/512
# 4/4 [==============================] - 0s 537us/step - loss: 0.0533 - accuracy: 1.0000 - mse: 0.0533
# Epoch 437/512
# 4/4 [==============================] - 0s 449us/step - loss: 0.0534 - accuracy: 1.0000 - mse: 0.0534
# Epoch 438/512
# 4/4 [==============================] - 0s 493us/step - loss: 0.0529 - accuracy: 1.0000 - mse: 0.0529
# Epoch 439/512
# 4/4 [==============================] - 0s 527us/step - loss: 0.0527 - accuracy: 1.0000 - mse: 0.0527
# Epoch 440/512
# 4/4 [==============================] - 0s 451us/step - loss: 0.0528 - accuracy: 1.0000 - mse: 0.0528
# Epoch 441/512
# 4/4 [==============================] - 0s 597us/step - loss: 0.0523 - accuracy: 1.0000 - mse: 0.0523
# Epoch 442/512
# 4/4 [==============================] - 0s 576us/step - loss: 0.0521 - accuracy: 1.0000 - mse: 0.0521
# Epoch 443/512
# 4/4 [==============================] - 0s 539us/step - loss: 0.0519 - accuracy: 1.0000 - mse: 0.0519
# Epoch 444/512
# 4/4 [==============================] - 0s 575us/step - loss: 0.0517 - accuracy: 1.0000 - mse: 0.0517
# Epoch 445/512
# 4/4 [==============================] - 0s 856us/step - loss: 0.0514 - accuracy: 1.0000 - mse: 0.0514
# Epoch 446/512
# 4/4 [==============================] - 0s 524us/step - loss: 0.0512 - accuracy: 1.0000 - mse: 0.0512
# Epoch 447/512
# 4/4 [==============================] - 0s 508us/step - loss: 0.0510 - accuracy: 1.0000 - mse: 0.0510
# Epoch 448/512
# 4/4 [==============================] - 0s 512us/step - loss: 0.0509 - accuracy: 1.0000 - mse: 0.0509
# Epoch 449/512
# 4/4 [==============================] - 0s 425us/step - loss: 0.0507 - accuracy: 1.0000 - mse: 0.0507
# Epoch 450/512
# 4/4 [==============================] - 0s 464us/step - loss: 0.0505 - accuracy: 1.0000 - mse: 0.0505
# Epoch 451/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.0503 - accuracy: 1.0000 - mse: 0.0503
# Epoch 452/512
# 4/4 [==============================] - 0s 513us/step - loss: 0.0501 - accuracy: 1.0000 - mse: 0.0501
# Epoch 453/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.0500 - accuracy: 1.0000 - mse: 0.0500
# Epoch 454/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.0497 - accuracy: 1.0000 - mse: 0.0497
# Epoch 455/512
# 4/4 [==============================] - 0s 454us/step - loss: 0.0495 - accuracy: 1.0000 - mse: 0.0495
# Epoch 456/512
# 4/4 [==============================] - 0s 496us/step - loss: 0.0498 - accuracy: 1.0000 - mse: 0.0498
# Epoch 457/512
# 4/4 [==============================] - 0s 409us/step - loss: 0.0492 - accuracy: 1.0000 - mse: 0.0492
# Epoch 458/512
# 4/4 [==============================] - 0s 456us/step - loss: 0.0490 - accuracy: 1.0000 - mse: 0.0490
# Epoch 459/512
# 4/4 [==============================] - 0s 446us/step - loss: 0.0488 - accuracy: 1.0000 - mse: 0.0488
# Epoch 460/512
# 4/4 [==============================] - 0s 553us/step - loss: 0.0490 - accuracy: 1.0000 - mse: 0.0490
# Epoch 461/512
# 4/4 [==============================] - 0s 450us/step - loss: 0.0485 - accuracy: 1.0000 - mse: 0.0485
# Epoch 462/512
# 4/4 [==============================] - 0s 486us/step - loss: 0.0483 - accuracy: 1.0000 - mse: 0.0483
# Epoch 463/512
# 4/4 [==============================] - 0s 553us/step - loss: 0.0485 - accuracy: 1.0000 - mse: 0.0485
# Epoch 464/512
# 4/4 [==============================] - 0s 809us/step - loss: 0.0479 - accuracy: 1.0000 - mse: 0.0479
# Epoch 465/512
# 4/4 [==============================] - 0s 663us/step - loss: 0.0477 - accuracy: 1.0000 - mse: 0.0477
# Epoch 466/512
# 4/4 [==============================] - 0s 485us/step - loss: 0.0480 - accuracy: 1.0000 - mse: 0.0480
# Epoch 467/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.0474 - accuracy: 1.0000 - mse: 0.0474
# Epoch 468/512
# 4/4 [==============================] - 0s 526us/step - loss: 0.0475 - accuracy: 1.0000 - mse: 0.0475
# Epoch 469/512
# 4/4 [==============================] - 0s 473us/step - loss: 0.0470 - accuracy: 1.0000 - mse: 0.0470
# Epoch 470/512
# 4/4 [==============================] - 0s 584us/step - loss: 0.0472 - accuracy: 1.0000 - mse: 0.0472
# Epoch 471/512
# 4/4 [==============================] - 0s 536us/step - loss: 0.0467 - accuracy: 1.0000 - mse: 0.0467
# Epoch 472/512
# 4/4 [==============================] - 0s 569us/step - loss: 0.0465 - accuracy: 1.0000 - mse: 0.0465
# Epoch 473/512
# 4/4 [==============================] - 0s 635us/step - loss: 0.0463 - accuracy: 1.0000 - mse: 0.0463
# Epoch 474/512
# 4/4 [==============================] - 0s 774us/step - loss: 0.0464 - accuracy: 1.0000 - mse: 0.0464
# Epoch 475/512
# 4/4 [==============================] - 0s 518us/step - loss: 0.0464 - accuracy: 1.0000 - mse: 0.0464
# Epoch 476/512
# 4/4 [==============================] - 0s 468us/step - loss: 0.0461 - accuracy: 1.0000 - mse: 0.0461
# Epoch 477/512
# 4/4 [==============================] - 0s 503us/step - loss: 0.0456 - accuracy: 1.0000 - mse: 0.0456
# Epoch 478/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.0454 - accuracy: 1.0000 - mse: 0.0454
# Epoch 479/512
# 4/4 [==============================] - 0s 477us/step - loss: 0.0455 - accuracy: 1.0000 - mse: 0.0455
# Epoch 480/512
# 4/4 [==============================] - 0s 476us/step - loss: 0.0455 - accuracy: 1.0000 - mse: 0.0455
# Epoch 481/512
# 4/4 [==============================] - 0s 567us/step - loss: 0.0449 - accuracy: 1.0000 - mse: 0.0449
# Epoch 482/512
# 4/4 [==============================] - 0s 677us/step - loss: 0.0451 - accuracy: 1.0000 - mse: 0.0451
# Epoch 483/512
# 4/4 [==============================] - 0s 582us/step - loss: 0.0446 - accuracy: 1.0000 - mse: 0.0446
# Epoch 484/512
# 4/4 [==============================] - 0s 657us/step - loss: 0.0447 - accuracy: 1.0000 - mse: 0.0447
# Epoch 485/512
# 4/4 [==============================] - 0s 927us/step - loss: 0.0443 - accuracy: 1.0000 - mse: 0.0443
# Epoch 486/512
# 4/4 [==============================] - 0s 523us/step - loss: 0.0441 - accuracy: 1.0000 - mse: 0.0441
# Epoch 487/512
# 4/4 [==============================] - 0s 519us/step - loss: 0.0439 - accuracy: 1.0000 - mse: 0.0439
# Epoch 488/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.0437 - accuracy: 1.0000 - mse: 0.0437
# Epoch 489/512
# 4/4 [==============================] - 0s 469us/step - loss: 0.0435 - accuracy: 1.0000 - mse: 0.0435
# Epoch 490/512
# 4/4 [==============================] - 0s 539us/step - loss: 0.0434 - accuracy: 1.0000 - mse: 0.0434
# Epoch 491/512
# 4/4 [==============================] - 0s 435us/step - loss: 0.0435 - accuracy: 1.0000 - mse: 0.0435
# Epoch 492/512
# 4/4 [==============================] - 0s 435us/step - loss: 0.0431 - accuracy: 1.0000 - mse: 0.0431
# Epoch 493/512
# 4/4 [==============================] - 0s 494us/step - loss: 0.0432 - accuracy: 1.0000 - mse: 0.0432
# Epoch 494/512
# 4/4 [==============================] - 0s 432us/step - loss: 0.0428 - accuracy: 1.0000 - mse: 0.0428
# Epoch 495/512
# 4/4 [==============================] - 0s 479us/step - loss: 0.0425 - accuracy: 1.0000 - mse: 0.0425
# Epoch 496/512
# 4/4 [==============================] - 0s 498us/step - loss: 0.0424 - accuracy: 1.0000 - mse: 0.0424
# Epoch 497/512
# 4/4 [==============================] - 0s 483us/step - loss: 0.0422 - accuracy: 1.0000 - mse: 0.0422
# Epoch 498/512
# 4/4 [==============================] - 0s 472us/step - loss: 0.0420 - accuracy: 1.0000 - mse: 0.0420
# Epoch 499/512
# 4/4 [==============================] - 0s 649us/step - loss: 0.0419 - accuracy: 1.0000 - mse: 0.0419
# Epoch 500/512
# 4/4 [==============================] - 0s 521us/step - loss: 0.0418 - accuracy: 1.0000 - mse: 0.0418
# Epoch 501/512
# 4/4 [==============================] - 0s 604us/step - loss: 0.0416 - accuracy: 1.0000 - mse: 0.0416
# Epoch 502/512
# 4/4 [==============================] - 0s 467us/step - loss: 0.0414 - accuracy: 1.0000 - mse: 0.0414
# Epoch 503/512
# 4/4 [==============================] - 0s 437us/step - loss: 0.0412 - accuracy: 1.0000 - mse: 0.0412
# Epoch 504/512
# 4/4 [==============================] - 0s 481us/step - loss: 0.0415 - accuracy: 1.0000 - mse: 0.0415
# Epoch 505/512
# 4/4 [==============================] - 0s 411us/step - loss: 0.0409 - accuracy: 1.0000 - mse: 0.0409
# Epoch 506/512
# 4/4 [==============================] - 0s 452us/step - loss: 0.0408 - accuracy: 1.0000 - mse: 0.0408
# Epoch 507/512
# 4/4 [==============================] - 0s 463us/step - loss: 0.0406 - accuracy: 1.0000 - mse: 0.0406
# Epoch 508/512
# 4/4 [==============================] - 0s 422us/step - loss: 0.0405 - accuracy: 1.0000 - mse: 0.0405
# Epoch 509/512
# 4/4 [==============================] - 0s 442us/step - loss: 0.0403 - accuracy: 1.0000 - mse: 0.0403
# Epoch 510/512
# 4/4 [==============================] - 0s 487us/step - loss: 0.0402 - accuracy: 1.0000 - mse: 0.0402
# Epoch 511/512
# 4/4 [==============================] - 0s 474us/step - loss: 0.0403 - accuracy: 1.0000 - mse: 0.0403
# Epoch 512/512
# 4/4 [==============================] - 0s 597us/step - loss: 0.0399 - accuracy: 1.0000 - mse: 0.0399

# %% [markdown]
# Note above that we've made it easy to vary the number of epochs.  This is worth exploring after we first cover some basics starting with tools to summarize the model fitting process. If you do this you will quickly discover that running too few epochs - and even just on some runs - the network does not converge upon an accuracy 1.0 solution.
#
# Keep in mind this data set is somewhat artificial - for exampl consisting of exactly four observations/samples. The simplicity of the data set noted, it is entirely sufficient to start trying out the basics.
#
# To start, ```summary``` will give an overview of the network, including how many parameters are used.  The ```None``` in the Output Shape column corresponds to the number of input values fed through the network.  ```summary``` must be called *after* ```fit```.

# %%
network1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# If we want to inspect where the weights are stored in a network we can use the ```_layers``` attribute of the network:

# %%
network1._layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7faef07267d0>,
#  <keras.layers.core.Dense at 0x7faea0e43190>,
#  <keras.layers.core.Dense at 0x7faea0e43390>]

# %% [markdown]
# Each of the elements in this list represents the things associated with one of the layers of the network.  The ```InputLayer``` doesn't actually interest us (it deals with reading in data), but we can look at the weights of the hidden layer:

# %%
foo = network1._layers[1].weights
foo
# Out:
# [<tf.Variable 'dense_1/kernel:0' shape=(2, 10) dtype=float32>,
#  <tf.Variable 'dense_1/bias:0' shape=(10,) dtype=float32>]

# %% [markdown]
# But it is **important** to take a moment and realize these weights are more than just a numpy array.  Seen as displayed above they are a data structre that came into existence when the network was compiled. But, they actually only have weight values after fitting.  And here is how you can examine (after fitting) the weights themselves.

# %%
foo = network1._layers[1].get_weights()
foo
# Out:
# [array([[ 0.6491705 , -0.30573004,  0.5540326 ,  0.2234635 , -0.7070817 ,
#           0.27428296, -0.27801427,  0.30648088, -0.08955431, -0.69268125],
#         [-0.6329768 ,  0.20711322,  0.402439  ,  0.22388798,  0.38187355,
#          -0.53257936, -0.05528349, -0.39798543, -0.19226265,  0.72415257]],
#        dtype=float32),
#  array([-1.0712114e-03, -3.7185260e-04, -3.2285199e-01, -2.2414783e-01,
#         -2.6468888e-01,  7.8565907e-05,  0.0000000e+00, -6.3542441e-02,
#          0.0000000e+00, -3.4233584e-04], dtype=float32)]

# %% [markdown]
# and the output layer:

# %%
print(network1._layers[2].get_weights())
# Out:
# [array([[-0.8969623 ],
#        [-0.2760958 ],
#        [ 0.3300585 ],
#        [ 0.5588145 ],
#        [ 0.2767314 ],
#        [-0.13011949],
#        [ 0.7291866 ],
#        [ 0.05689288],
#        [-0.19703722],
#        [-0.7082453 ]], dtype=float32), array([0.6539604], dtype=float32)]

# %% [markdown]
# We can also use the network for prediction:

# %%
print(X_xor)
print(network1.predict(X_xor))
# Out:
# [[0. 0.]
#  [1. 0.]
#  [0. 1.]
#  [1. 1.]]
# [[0.65395015]
#  [0.12706459]
#  [0.14294183]
#  [0.95221007]]

# %% [markdown]
# Remember that the network is trying to approximate the values [1, 0, 0, 1].  Let's look at the history of the loss and accuracy over the epochs of training the network using the ```history``` of the trained network:

# %%
plt.plot(history1.history['accuracy'], label='Accuracy')
plt.plot(history1.history['mse'], label='MSE')
plt.ylim([0, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# Let's also look at the decision surface of this network:

# %%
plot_XOR_network(network1)

# %% [markdown]
# We can also add more layers and have more nodes in each layer:

# %%
network2 = keras.Sequential()
network2.add(keras.layers.Dense(50, activation='relu'))
network2.add(keras.layers.Dense(25, activation='relu'))
network2.add(keras.layers.Dense(12, activation='relu'))
network2.add(keras.layers.Dense(1))

loss_fn = keras.losses.MeanSquaredError()
opt = keras.optimizers.SGD(learning_rate=0.005)
network2.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

history2 = network2.fit(X_xor, y_xor, batch_size=1, epochs=512, verbose=0)

# %%
network2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 50)                150
# _________________________________________________________________
# dense_4 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                312
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 1,750
# Trainable params: 1,750
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This model has far more complexity than is necessary for this problem - a total of 1,750 parameters is orders of magnitude larger than necessary, but it still finds a good solution.

# %%
plt.plot(history2.history['accuracy'], label='Accuracy')
plt.plot(history2.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %%
plot_XOR_network(network2)

# %% [markdown]
# ## One hot encoding, Softmax and the Loss Function

# %% [markdown]
# ## One hot encoding
#
# Using the Euclidean distance of the outputs from the true values probably isn't the best loss function to be using: it is designed for regression problems. Instead, we can use the cross entropy loss (yes we are introducing a new term which will be defined shortly).
#
# To do this, one thing we need to do is change our expected outputs from being 0 or 1 to be one-hot-encoded:

# %%
y_xor
# Out:
# array([1, 0, 0, 1])

# %%
y_xor_one_hot = keras.utils.to_categorical(y_xor, 2)

for a,b in zip(y_xor, y_xor_one_hot) :
    print(f'y value {a} maps to the encoding {b}')
# Out:
# y value 1 maps to the encoding [0. 1.]
# y value 0 maps to the encoding [1. 0.]
# y value 0 maps to the encoding [1. 0.]
# y value 1 maps to the encoding [0. 1.]

# %% [markdown]
# In one-hot-encoding, each output is now a vector with zero at each class label that is not correct for the associated input and one at the class label that is correct.  One thing to note with this modification is that our network will now have two outputs.
#
# It's also useful to restrict the outputs of our network to look like probabilities.  One way to do this would be to normalize the outputs to be
# \begin{align*}
# z_1' &= \frac{z_1}{z_1 + z_2} \\
# z_2' &= \frac{z_2}{z_1 + z_2}
# \end{align*}
# which gives us $z_1'$ and $z_2'$ values each between zero and one and summing to one.  One thing to keep in mind here is that although these now form a probability distribution, it isn't necessarily accurate to view $z_1'$ as the "probability that the input is of class one" because the approximation given by our network is just that - an approximation. While useful from a pracitcal standpoint it should not be confused with a rigorously established estimate of the true underlying probability.
#
#
# Another way to do this would be to take the hard max of the outputs,
# \begin{align*}
# z_1' &= \begin{cases} 1 & z_1 \geq z_2 \\ 0 & z_1 < z_2 \end{cases} \\
# z_2' &= \begin{cases} 0 & z_1 \geq z_2 \\ 1 & z_1 < z_2 \end{cases},
# \end{align*}
# which has similar nice properties but is unfortunately not differentiable, so we can't actually use it for classification.
#
# A compromise between these two is softmax.  For our two raw outputs, $z_1$ and $z_2$, the softmax activation function is calculated as
# \begin{align*}
# \text{softmax}(z_1) &= \frac{e^{z_1}}{e^{z_1} + e^{z_2}} \\
# \text{softmax}(z_2) &= \frac{e^{z_2}}{e^{z_1} + e^{z_2}}
# \end{align*}
#
# This is very similar to normalization, but with the exponential function of the raw inputs instead.  This means that values will behave in a manner similar to the softwax while maintaining differentiability.

# %% [markdown]
# ### Visualizing Softmax
#
# Here is a simple bit of code to help you visualize what happens when a set of activations on the last layer of a classification network are run through the softmax function.

# %%
def apply_softmax(acts) :
    exp_acts = np.array([np.exp(x) for x in acts])
    exp_acts_sum = np.sum(exp_acts)
    acts_smax = np.array([np.exp(x)/exp_acts_sum for x in acts])
    return exp_acts, acts_smax

def visualize_softmax(mean, sigma, nsamples, rseed) :
    rng = default_rng(rseed)
    act = rng.normal(mean, sigma, nsamples)
    aex, asf = apply_softmax(act)
    plt.style.use('seaborn-deep')
    fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(13,5))
    ax1.bar(range(nsamples), act, color='darkred')
    ax1.set_xlabel('Output Node')
    ax1.set_ylabel('Activation')
    ax1.set_title('Input Activations')   
    ax2.bar(range(nsamples), aex, color='darkblue')
    ax2.set_xlabel('Output Node')
    ax2.set_ylabel('After Exponentiation')
    ax2.set_title('Exponentiated Input Activation')  
    ax3.bar(range(nsamples), asf, color='darkgreen')
    ax3.set_xlabel('Output Node')
    ax3.set_ylabel('Activation')
    ax3.set_title('Softmax applied to Activations')
    
    plt.show()

# %%
# rseed of 82 is nice illustration
rseed = np.random.randint(0,99)
visualize_softmax(5, 1.0, 8, rseed)
print(f'Random seed is: {rseed}')
# Out:
# Random seed is: 83

# %% [markdown]
# ### XOR and a One Hot Softmax Output
#
# Our third network still solves XOR but with the one hot encoding and softmax just introduced. Also, the loss function is now Cross Entropy.
#
# And repeating the disclaimer above - each time you run the following code you train up a new instance of the neural network. Most, but not all of these, will perfectly solve the XOR problem.

# %%
hidden_layer_width = 2
accuracy_threshold = 0.78
instance  = 1
# max_tries = 8
max_tries = 32
while True:
    network3 = keras.Sequential()
    network3.add(keras.layers.Dense(hidden_layer_width, activation='relu'))
    network3.add(keras.layers.Dense(2, activation='softmax'))
    loss_fn = keras.losses.BinaryCrossentropy()
    opt     = keras.optimizers.SGD(learning_rate=0.01)
    network3.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    history3 = network3.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=600, verbose=0)
    accu = history3.history['accuracy'][-1]
    print(f'Network instance {instance} achieved {accu:.5f}')
    instance += 1
    if history3.history['accuracy'][-1] > accuracy_threshold :
        print(f'Found a network exceeding accuracy threshold {accuracy_threshold}')
        break 
    if instance > max_tries : break
# Out:
# WARNING:tensorflow:From /Users/ross/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Network instance 1 achieved 0.75000
# Network instance 2 achieved 0.00000
# Network instance 3 achieved 0.50000
# Network instance 4 achieved 0.75000
# Network instance 5 achieved 0.75000
# Network instance 6 achieved 0.75000
# Network instance 7 achieved 0.50000
# Network instance 8 achieved 0.25000
# Network instance 9 achieved 0.75000
# Network instance 10 achieved 0.25000
# Network instance 11 achieved 1.00000
# Found a network exceeding accuracy threshold 0.78

# %%
plt.plot(history3.history['accuracy'], label='Accuracy')
plt.plot(history3.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# To visualize the decision surface, we will plot $z_1 - z_2$.  This is a trick we will use throughout the rest of the notebook.

# %%
plot_XOR_network(network3, two_outputs=True)

# %% [markdown]
# ## Nonconvex Optimization

# %% [markdown]
# For linear models, finding a solution that minimizes some quantity of interest was relatively easy because the error surface has a single global minimum.  Whenever the error function satisfies a certain condition known as "convexity", this is guaranteed to be the case.
# Here's an example of a loss surface of a convex problem:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2)
points = np.r_[True, y[1:] <= y[:-1]] & np.r_[y[:-1] <= y[1:], True]
plt.plot(x, y, label='Loss Surface')
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.title("Convex Optimization")
plt.xticks([])
plt.yticks([])
plt.scatter(x[points], y[points], c='r', label='minimum')
plt.legend();

# %% [markdown]
# As we change the weights of the model, we move around on the blue curve.  The goal is to find a configuration of weights that places us at the location of the red dot, which is the minimum of this function.

# %% [markdown]
# However, due to the nonlinearity of neural networks, there may be more than one minimum.  For example:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2) + 5*np.sin(np.pi*x)
points = np.r_[True, y[1:] < y[:-1]] & np.r_[y[:-1] < y[1:], True]
plt.plot(x, y, label="Loss Surface")
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.xticks([])
plt.yticks([])
plt.title("Nonconvex Optimization")
plt.scatter(x[points], y[points], c='r', label='minima')
plt.legend();

# %% [markdown]
# In this case, there is a single global minimum that represents the optimal solution, but there are a number of other *local* minima.
#
# Gradient descent and many of its variants are the most commonly used algorithms for optimizing the weights of neural networks.  Gradient descent can be thought of as behaving like a ball that is placed on the the loss surface - it rolls down hills.  That means that if an initial configuration of a neural network lies somewhere in a valley around one of the local minima, gradient descent will push it towards that local minimum rather than the global minimum.
# However, that may or may not be a problem!  We are interested in solutions that have high prediction accuracy - not necessarily finding the global minimum.

# %% [markdown]
# ## Gradient Descent Modifications and Regularization

# %% [markdown]
# The simple SGD algorithm has a modification that can help with shallow local minima and plateaus in the loss surface - momentum.  Intuitively, this is the same as the idea would be in physics, where the model builds momentum as it travels, and can continue to follow that momentum rather than just going in the direction of most change.  This helps avoid shallow local minima and can prevent the model from slowing down too much on plateaus.

# %% [markdown]
# We can also add weight decay to our model, where weights are driven towards small values to reduce the likelihood of overfitting and smooth the loss surface:

# %%
hidden_width = 2
accuracy_threshold = 0.78
instance  = 1
max_tries = 16
while True:
    opt = keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)
    reg = keras.regularizers.l2(1e-4)
    loss_fn = keras.losses.BinaryCrossentropy()
    network4 = keras.Sequential()
    network4.add(keras.layers.Dense(hidden_width, activation='relu', kernel_regularizer=reg, bias_regularizer=reg))
    network4.add(keras.layers.Dense(2, activation='softmax', kernel_regularizer=reg, bias_regularizer=reg))
    network4.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    history4 = network4.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=600, verbose=0)
    accu = history4.history['accuracy'][-1]
    print(f'Network instance {instance} achieved {accu:.5f}')
    instance += 1
    if history4.history['accuracy'][-1] > accuracy_threshold :
        print(f'Found a network exceeding accuracy threshold {accuracy_threshold}')
        break 
    if instance > max_tries : break
# Out:
# Network instance 1 achieved 1.00000
# Found a network exceeding accuracy threshold 0.78

# %% [markdown]
# The rest of our setup is the same as it has been previously.

# %%
plt.plot(history4.history['accuracy'], label='Accuracy')
plt.plot(history4.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# This network trains *much* faster than the previous models.  While testing this notebook, the model frequently achieved zero loss by epoch 50.

# %%
plot_XOR_network(network4, two_outputs=True)

# %% [markdown]
# There are also more complex optimizers, such as the [Adam optimizer](https://arxiv.org/pdf/1412.6980.pdf) designed by Diederik Kingma and Jimmy Ba.  It uses a variety of techniques like adaptive learning rates and momentums to provide competitive performance.  To use it in Keras, call it as

# %%
opt = keras.optimizers.Adam()

# %% [markdown]
# It has default parameters that empirically work well on a wide class of problems.

# %% [markdown]
# ## Complex Problems

# %% [markdown]
# [Neural Networks, Manifolds, and Topology](https://colah.github.io/posts/2014-03-NN-Manifolds-Topology/) by Christopher Olah has animated versions for $\tanh$ networks of some of the investigations and examples shown here.

# %% [markdown]
# Now let's consider a slightly more difficult problem for neural networks:

# %%
r1 = 0.5
r2 = np.sqrt(2*r1**2)
r3 = np.sqrt(r1**2 + r2**2)

fig = plt.figure()
ax = fig.add_subplot(111)

circle = plt.Circle((0, 0), r1)
annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, color='r')
ax.add_artist(circle)
ax.add_artist(annulus)
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# By itself this is a relatively easy problem - if we convert to polar coordinates, we can just threshold based on the radius and have a very simple classifier that achieves 100% accuracy.  However, if we use the raw $x_1$ and $x_2$ inputs to a neural network, that information must be learned by the network.  The network must be able to construct a closed region in the plane, which requires more complexity than was necessary for XOR.
#
# For training a network we need specific inputs, so we will get 500 points from the circle and 500 from the annulus with their associated class labels:

# %%
X_circle = []
y_circle = []
for i in range(500):
    # Circle
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) > r1:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(0)
        
    # Annulus
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) < r2 or np.linalg.norm(vec) > r3:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(1)
    
X_circle = np.array(X_circle)
X_circle = X_circle.astype('float32')
y_circle = np.array(y_circle)
y_circle_one_hot = keras.utils.to_categorical(y_circle, 2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X_circle[y_circle==0, 0], X_circle[y_circle==0, 1])
ax.scatter(X_circle[y_circle==1, 0], X_circle[y_circle==1, 1], c='r')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# Let's train a simple network on this and keep trying until we make sure we get a better solution than random:

# %%
hidden_width = 2
accuracy_threshold = 0.78
instance  = 1
max_tries = 8
while True:
    network5 = keras.Sequential()
    network5.add(keras.layers.Dense(hidden_width, activation='relu'))
    network5.add(keras.layers.Dense(2, activation='softmax'))

    loss_fn = keras.losses.BinaryCrossentropy()
    opt = keras.optimizers.Adam()
    network5.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    
    history5 = network5.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    accu = history5.history['accuracy'][-1]
    print(f'Network instance {instance} achieved {accu:.5f}')
    instance += 1
    if history5.history['accuracy'][-1] > accuracy_threshold :
        print(f'Found a network exceeding accuracy threshold {accuracy_threshold}')
        break
    if instance > max_tries : break
# Out:
# Network instance 1 achieved 0.64400
# Network instance 2 achieved 0.80300
# Found a network exceeding accuracy threshold 0.78

# %%
plt.plot(history5.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network5, two_outputs=True)

# %% [markdown]
# **Comment/Warning** - the next three paragraphs describe one possible solution, not necessarily the one you are seeing. This is because the network - each time it is trained - finds somewhat different solutions.
#
# This network gets about 80% accuracy, which is somewhat close to the best that can be expected from this architecture.  Let's look at what it actually does to the data.  The first thing it does is apply the weights of the first layer to transform the data:

# %% [markdown]
# Every data point with a horizontal coordinate below zero has its horizontal coordinate taken to zero - effectively shoving all the negative data to zero on that axis.
#
# We can do the same thing with the second node, which is the vertical axis:

# %% [markdown]
# This doesn't look particularly useful, but notice that all of the blue data points are in the lower left corner.  That means that when the decision boundary is drawn on, they can (mostly) be on one side, even if there is significant mixing with the red points.
#
# That decision boundary comes from the hidden to output weights, as that is the linear classifier the network is using.  In the new space created by applying the first layer, the decision boundary is a straight line:

# %% [markdown]
# Now let's train a network that solves this, with three nodes in its hidden layer.  We may have to train it multiple times for it to find a solution with 100% accuracy.

# %%
hidden_width = 3
accuracy_threshold = 0.996
instance  = 1
max_tries = 8
while True:
    accuracy_threshold = 0.996
    network6 = keras.Sequential()
    network6.add(keras.layers.Dense(hidden_width, activation='relu'))
    network6.add(keras.layers.Dense(2, activation='softmax'))

    loss_fn = keras.losses.BinaryCrossentropy()
    opt = keras.optimizers.Adam()
    network6.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
   
    history6 = network6.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    accu = history6.history['accuracy'][-1]
    print(f'Network instance {instance} achieved {accu:.5f}')
    instance += 1
    if history6.history['accuracy'][-1] >= accuracy_threshold :
        print(f'Found a network exceeding accuracy threshold {accuracy_threshold}')
        break
    if instance > max_tries : break
# Out:
# Network instance 1 achieved 0.79600
# Network instance 2 achieved 0.81600
# Network instance 3 achieved 0.78000
# Network instance 4 achieved 0.99700
# Found a network exceeding accuracy threshold 0.996

# %%
plt.plot(history6.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network6, two_outputs=True)

# %% [markdown]
# This should have perfect or near perfect accuracy on the data we are considering - if it is perfect, it likely has a hexagonal shape, and if it is imperfect it has like found a square shape with the corners overlapping the annulus.

# %% [markdown]
# ## Comments
#
# 1. Some of the intuition from these small, two-input networks may not carry over in expected ways to higher dimensional problems.  Unfortunately, building intuition for those more complex problems is typically difficult due to the limited ability to analyze high dimensional networks.  We will discuss more complex problems in our next notebook.
# 2. Until relatively recently, one of the best methods for hyperparameter selection with neural networks was random search.  More sophisticated methods exist now, but without insight into the dataset it can be difficult to determine how to structure network architecture and training process
# 3. Keras used to be independent from the chosen backend, but its creator now works for Google (the makers of TensorFlow), and backends like PyTorch are no longer being updated, so the "recommended" backend is TensorFlow.  Keras is also being more closely tied into TensorFlow.
